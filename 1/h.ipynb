# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NLP/Project3
# 1/  3/        glove.6B.50d.txt  Project_show.ipynb
# 2/  dataset/  Project_3.ipynb   sample_3.ipynb

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#five gram

sequences_train = list()
for i in range(4, len(encoded_train)):
    sequence_train = encoded_train[i-3:i+2]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(4, len(encoded_test)):
    sequence_test = encoded_test[i-3:i+2]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57048
# Total Sequences test: 12344

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 5
# Max Sequences test Length: 5

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras (see above)
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(35, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 35)                7035
# _________________________________________________________________
# dropout (Dropout)            (None, 35)                0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15301)             550836
# =================================================================
# Total params: 20,557,921
# Trainable params: 557,871
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 9s 3ms/step - loss: 9.5483 - perplexity: 769.9697
# Epoch 2/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 9.3269 - perplexity: 724.8901
# Epoch 3/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 9.1730 - perplexity: 679.0164
# Epoch 4/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 9.0258 - perplexity: 646.9346
# Epoch 5/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.9092 - perplexity: 629.8713
# Epoch 6/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.8281 - perplexity: 621.2082
# Epoch 7/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.7658 - perplexity: 617.8604
# Epoch 8/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.7314 - perplexity: 616.4357
# Epoch 9/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.7089 - perplexity: 617.0237
# Epoch 10/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6797 - perplexity: 617.6558
# Epoch 11/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.6611 - perplexity: 617.2304
# Epoch 12/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.6413 - perplexity: 616.2929
# Epoch 13/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6272 - perplexity: 616.4534
# Epoch 14/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6220 - perplexity: 617.8178
# Epoch 15/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6092 - perplexity: 620.6127
# Epoch 16/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6042 - perplexity: 621.6039
# Epoch 17/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5910 - perplexity: 621.5226
# Epoch 18/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5764 - perplexity: 620.1758
# Epoch 19/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5893 - perplexity: 625.4583
# Epoch 20/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5734 - perplexity: 625.0813
# Epoch 21/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5760 - perplexity: 624.0471
# Epoch 22/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5584 - perplexity: 624.2863
# Epoch 23/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5601 - perplexity: 628.2295
# Epoch 24/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5637 - perplexity: 627.4858
# Epoch 25/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5478 - perplexity: 624.5050
# Epoch 26/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5476 - perplexity: 627.9771
# Epoch 27/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5425 - perplexity: 626.1161
# Epoch 28/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5436 - perplexity: 627.0370
# Epoch 29/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5451 - perplexity: 627.0884
# Epoch 30/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5360 - perplexity: 624.9151
# Epoch 31/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5402 - perplexity: 625.7473
# Epoch 32/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.5349 - perplexity: 629.1231
# Epoch 33/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5351 - perplexity: 627.0787
# Epoch 34/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5325 - perplexity: 626.6966
# Epoch 35/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5141 - perplexity: 623.9030
# Epoch 36/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5228 - perplexity: 625.9167
# Epoch 37/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5258 - perplexity: 630.3341
# Epoch 38/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5194 - perplexity: 627.0376
# Epoch 39/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5176 - perplexity: 629.7406
# Epoch 40/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5335 - perplexity: 631.0300
# Epoch 41/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5243 - perplexity: 630.2410
# Epoch 42/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5069 - perplexity: 626.2929
# Epoch 43/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5078 - perplexity: 625.6368
# Epoch 44/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5172 - perplexity: 629.0984
# Epoch 45/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5196 - perplexity: 629.7423
# Epoch 46/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5091 - perplexity: 630.2357
# Epoch 47/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5085 - perplexity: 628.4562
# Epoch 48/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5062 - perplexity: 626.7502
# Epoch 49/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4957 - perplexity: 628.4550
# Epoch 50/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5025 - perplexity: 629.1420
# Epoch 51/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5024 - perplexity: 630.9929
# Epoch 52/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4957 - perplexity: 629.0708
# Epoch 53/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4996 - perplexity: 630.4946
# Epoch 54/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.4902 - perplexity: 627.6565
# Epoch 55/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4971 - perplexity: 628.3431
# Epoch 56/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4802 - perplexity: 627.1412
# Epoch 57/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4847 - perplexity: 627.4172
# Epoch 58/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4876 - perplexity: 627.8383
# Epoch 59/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4878 - perplexity: 629.9901
# Epoch 60/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4887 - perplexity: 630.9799
# Epoch 61/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4981 - perplexity: 632.1381
# Epoch 62/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4790 - perplexity: 629.3875
# Epoch 63/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4678 - perplexity: 625.6748
# Epoch 64/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4854 - perplexity: 628.7384
# Epoch 65/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4770 - perplexity: 627.2682
# Epoch 66/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4876 - perplexity: 630.2178
# Epoch 67/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4690 - perplexity: 628.5723
# Epoch 68/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4723 - perplexity: 629.2769
# Epoch 69/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4755 - perplexity: 631.4374
# Epoch 70/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4723 - perplexity: 630.3715
# Epoch 71/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4608 - perplexity: 628.1271
# Epoch 72/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4676 - perplexity: 629.5748
# Epoch 73/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.4636 - perplexity: 626.5009
# Epoch 74/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4632 - perplexity: 631.7075
# Epoch 75/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4524 - perplexity: 629.1486
# Epoch 76/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4523 - perplexity: 627.3969
# Epoch 77/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4728 - perplexity: 634.5980
# Epoch 78/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4644 - perplexity: 631.6455
# Epoch 79/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4627 - perplexity: 631.8153
# Epoch 80/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4348 - perplexity: 624.3543
# Epoch 81/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4672 - perplexity: 633.2850
# Epoch 82/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4500 - perplexity: 629.6712
# Epoch 83/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4544 - perplexity: 629.1384
# Epoch 84/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4471 - perplexity: 629.1841
# Epoch 85/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4490 - perplexity: 629.1636
# Epoch 86/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4525 - perplexity: 630.4632
# Epoch 87/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4440 - perplexity: 626.0568
# Epoch 88/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4521 - perplexity: 632.3796
# Epoch 89/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4454 - perplexity: 627.7601
# Epoch 90/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4598 - perplexity: 632.1438
# Epoch 91/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4418 - perplexity: 627.7433
# Epoch 92/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4413 - perplexity: 626.9523
# Epoch 93/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4351 - perplexity: 626.5830
# Epoch 94/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4432 - perplexity: 627.9006
# Epoch 95/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4376 - perplexity: 627.5877
# Epoch 96/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.4360 - perplexity: 628.5787
# Epoch 97/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4368 - perplexity: 626.0225
# Epoch 98/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4425 - perplexity: 632.2542
# Epoch 99/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4300 - perplexity: 623.4292
# Epoch 100/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4471 - perplexity: 630.0646
#
# --------evaluate---------
# 386/386 [==============================] - 1s 3ms/step - loss: 8.6315 - perplexity: 558.8427
# [8.631499290466309, 558.8427124023438]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(35, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.03,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 35)                7035
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 35)                0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15301)             550836
# =================================================================
# Total params: 20,557,921
# Trainable params: 557,871
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 9.4429 - perplexity: 748.4941
# Epoch 2/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.9737 - perplexity: 642.1187
# Epoch 3/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.7495 - perplexity: 618.7335
# Epoch 4/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6639 - perplexity: 618.5576
# Epoch 5/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6249 - perplexity: 620.7380
# Epoch 6/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6060 - perplexity: 624.8040
# Epoch 7/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5946 - perplexity: 628.7011
# Epoch 8/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5747 - perplexity: 628.8511
# Epoch 9/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5586 - perplexity: 633.1366
# Epoch 10/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5465 - perplexity: 628.9841
# Epoch 11/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5490 - perplexity: 630.8965
# Epoch 12/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5417 - perplexity: 630.5572
# Epoch 13/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5326 - perplexity: 628.9750
# Epoch 14/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.5282 - perplexity: 629.9920
# Epoch 15/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5217 - perplexity: 630.6543
# Epoch 16/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.5170 - perplexity: 630.7972
# Epoch 17/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5097 - perplexity: 633.3768
# Epoch 18/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5130 - perplexity: 630.2298
# Epoch 19/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5097 - perplexity: 632.4488
# Epoch 20/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4898 - perplexity: 628.2422
# Epoch 21/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4867 - perplexity: 626.6717
# Epoch 22/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4883 - perplexity: 631.0348
# Epoch 23/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4752 - perplexity: 628.8284
# Epoch 24/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4699 - perplexity: 628.3565
# Epoch 25/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4562 - perplexity: 627.3570
# Epoch 26/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4699 - perplexity: 631.5568
# Epoch 27/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4592 - perplexity: 628.8919
# Epoch 28/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4757 - perplexity: 632.9591
# Epoch 29/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4682 - perplexity: 633.2950
# Epoch 30/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4497 - perplexity: 629.4419
# Epoch 31/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4437 - perplexity: 628.9652
# Epoch 32/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4333 - perplexity: 627.0163
# Epoch 33/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4350 - perplexity: 628.1832
# Epoch 34/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4307 - perplexity: 627.4760
# Epoch 35/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4357 - perplexity: 630.9125
# Epoch 36/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4374 - perplexity: 628.2666
# Epoch 37/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.4318 - perplexity: 631.0960
# Epoch 38/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.4247 - perplexity: 628.6540
# Epoch 39/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4197 - perplexity: 626.5739
# Epoch 40/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4198 - perplexity: 624.9267
# Epoch 41/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4203 - perplexity: 626.8667
# Epoch 42/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4249 - perplexity: 627.1805
# Epoch 43/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4051 - perplexity: 627.0288
# Epoch 44/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4011 - perplexity: 623.2752
# Epoch 45/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3874 - perplexity: 617.2474
# Epoch 46/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4136 - perplexity: 622.3330
# Epoch 47/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4137 - perplexity: 625.6626
# Epoch 48/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4062 - perplexity: 622.6769
# Epoch 49/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3842 - perplexity: 618.5403
# Epoch 50/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3927 - perplexity: 617.1809
# Epoch 51/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3854 - perplexity: 617.5845
# Epoch 52/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3992 - perplexity: 620.7255
# Epoch 53/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3818 - perplexity: 615.0145
# Epoch 54/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3884 - perplexity: 616.4262
# Epoch 55/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3687 - perplexity: 613.7686
# Epoch 56/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.3776 - perplexity: 613.2246
# Epoch 57/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3594 - perplexity: 611.4926
# Epoch 58/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3764 - perplexity: 611.3452
# Epoch 59/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3724 - perplexity: 611.6903
# Epoch 60/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3589 - perplexity: 607.9452
# Epoch 61/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3442 - perplexity: 604.6368
# Epoch 62/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3651 - perplexity: 606.6841
# Epoch 63/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3584 - perplexity: 605.8392
# Epoch 64/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3529 - perplexity: 601.1683
# Epoch 65/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3525 - perplexity: 603.1670
# Epoch 66/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3554 - perplexity: 602.1626
# Epoch 67/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3509 - perplexity: 602.9785
# Epoch 68/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3495 - perplexity: 601.9927
# Epoch 69/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3335 - perplexity: 598.1364
# Epoch 70/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3477 - perplexity: 600.1195
# Epoch 71/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3411 - perplexity: 597.5669
# Epoch 72/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3397 - perplexity: 593.0339
# Epoch 73/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3259 - perplexity: 594.0772
# Epoch 74/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3179 - perplexity: 591.2373
# Epoch 75/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3261 - perplexity: 592.9419
# Epoch 76/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3266 - perplexity: 592.8331
# Epoch 77/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3106 - perplexity: 588.1706
# Epoch 78/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3091 - perplexity: 587.0960
# Epoch 79/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.3132 - perplexity: 587.6869
# Epoch 80/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.3079 - perplexity: 587.6158
# Epoch 81/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3027 - perplexity: 583.4033
# Epoch 82/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3008 - perplexity: 584.3524
# Epoch 83/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2930 - perplexity: 584.0964
# Epoch 84/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2980 - perplexity: 582.1869
# Epoch 85/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2868 - perplexity: 577.1487
# Epoch 86/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2858 - perplexity: 576.2929
# Epoch 87/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2950 - perplexity: 580.2392
# Epoch 88/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2810 - perplexity: 573.1661
# Epoch 89/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2715 - perplexity: 573.4799
# Epoch 90/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2878 - perplexity: 572.9372
# Epoch 91/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2933 - perplexity: 578.7621
# Epoch 92/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2773 - perplexity: 570.2597
# Epoch 93/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2590 - perplexity: 569.5295
# Epoch 94/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2679 - perplexity: 567.1425
# Epoch 95/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2653 - perplexity: 566.3267
# Epoch 96/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2455 - perplexity: 563.0526
# Epoch 97/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2608 - perplexity: 562.1390
# Epoch 98/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.2430 - perplexity: 561.4379
# Epoch 99/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2405 - perplexity: 558.7074
# Epoch 100/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2515 - perplexity: 561.6334
#
# --------evaluate---------
# 386/386 [==============================] - 1s 3ms/step - loss: 8.6681 - perplexity: 570.4092
# [8.66810417175293, 570.4092407226562]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(35, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.1,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 35)                7035
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 35)                0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 15301)             550836
# =================================================================
# Total params: 20,557,921
# Trainable params: 557,871
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 9.2226 - perplexity: 704.7536
# Epoch 2/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.6640 - perplexity: 632.5827
# Epoch 3/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5817 - perplexity: 632.8902
# Epoch 4/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5555 - perplexity: 632.2454
# Epoch 5/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5219 - perplexity: 632.6564
# Epoch 6/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.5052 - perplexity: 632.4966
# Epoch 7/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4869 - perplexity: 632.1751
# Epoch 8/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4597 - perplexity: 629.3977
# Epoch 9/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4531 - perplexity: 626.8786
# Epoch 10/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4479 - perplexity: 629.4729
# Epoch 11/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4449 - perplexity: 632.1114
# Epoch 12/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4265 - perplexity: 627.5370
# Epoch 13/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4235 - perplexity: 624.9165
# Epoch 14/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.4032 - perplexity: 618.7745
# Epoch 15/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3991 - perplexity: 612.7682
# Epoch 16/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3795 - perplexity: 609.3219
# Epoch 17/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3644 - perplexity: 605.8165
# Epoch 18/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3461 - perplexity: 600.7456
# Epoch 19/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3495 - perplexity: 597.9020
# Epoch 20/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3442 - perplexity: 596.7478
# Epoch 21/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.3232 - perplexity: 591.0281
# Epoch 22/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.3154 - perplexity: 587.1758
# Epoch 23/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.3089 - perplexity: 582.3693
# Epoch 24/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2861 - perplexity: 574.3053
# Epoch 25/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2850 - perplexity: 571.1215
# Epoch 26/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2617 - perplexity: 563.6769
# Epoch 27/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2553 - perplexity: 559.4025
# Epoch 28/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2303 - perplexity: 553.0914
# Epoch 29/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2283 - perplexity: 549.6882
# Epoch 30/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2056 - perplexity: 545.3481
# Epoch 31/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.2122 - perplexity: 542.0909
# Epoch 32/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.1713 - perplexity: 534.3628
# Epoch 33/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.1721 - perplexity: 528.9008
# Epoch 34/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.1616 - perplexity: 527.6647
# Epoch 35/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.1421 - perplexity: 518.2435
# Epoch 36/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.1322 - perplexity: 512.5328
# Epoch 37/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.1239 - perplexity: 510.6504
# Epoch 38/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0967 - perplexity: 502.2188
# Epoch 39/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 8.0978 - perplexity: 499.5270
# Epoch 40/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0824 - perplexity: 495.4978
# Epoch 41/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0702 - perplexity: 489.1926
# Epoch 42/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0540 - perplexity: 483.3470
# Epoch 43/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0190 - perplexity: 475.4618
# Epoch 44/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0190 - perplexity: 473.3694
# Epoch 45/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 8.0073 - perplexity: 467.4570
# Epoch 46/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9923 - perplexity: 462.6938
# Epoch 47/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9878 - perplexity: 458.3106
# Epoch 48/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9745 - perplexity: 452.3391
# Epoch 49/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9688 - perplexity: 451.8261
# Epoch 50/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9557 - perplexity: 444.3870
# Epoch 51/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9393 - perplexity: 440.3801
# Epoch 52/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9132 - perplexity: 434.4048
# Epoch 53/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.9052 - perplexity: 429.3510
# Epoch 54/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8899 - perplexity: 423.5860
# Epoch 55/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8815 - perplexity: 420.6449
# Epoch 56/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8596 - perplexity: 414.2612
# Epoch 57/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8647 - perplexity: 411.2592
# Epoch 58/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8563 - perplexity: 408.4195
# Epoch 59/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8428 - perplexity: 405.6352
# Epoch 60/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8177 - perplexity: 399.2585
# Epoch 61/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.8146 - perplexity: 394.4009
# Epoch 62/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7988 - perplexity: 389.1576
# Epoch 63/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 7.7833 - perplexity: 385.7590
# Epoch 64/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 7.7747 - perplexity: 382.3014
# Epoch 65/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7677 - perplexity: 377.7878
# Epoch 66/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7552 - perplexity: 375.4300
# Epoch 67/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7446 - perplexity: 371.4670
# Epoch 68/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7140 - perplexity: 365.6009
# Epoch 69/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7196 - perplexity: 362.9722
# Epoch 70/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.7068 - perplexity: 360.0810
# Epoch 71/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6912 - perplexity: 353.8991
# Epoch 72/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6782 - perplexity: 349.5252
# Epoch 73/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6694 - perplexity: 346.8605
# Epoch 74/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6708 - perplexity: 345.2134
# Epoch 75/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6624 - perplexity: 342.3209
# Epoch 76/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6371 - perplexity: 337.0544
# Epoch 77/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6257 - perplexity: 332.6822
# Epoch 78/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.6197 - perplexity: 330.8109
# Epoch 79/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5918 - perplexity: 324.9623
# Epoch 80/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 7.6091 - perplexity: 325.0489
# Epoch 81/100
# 2282/2282 [==============================] - 8s 3ms/step - loss: 7.5702 - perplexity: 318.0374
# Epoch 82/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5650 - perplexity: 315.8674
# Epoch 83/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5644 - perplexity: 313.7496
# Epoch 84/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5519 - perplexity: 310.9266
# Epoch 85/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5383 - perplexity: 307.7044
# Epoch 86/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5353 - perplexity: 305.2522
# Epoch 87/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5137 - perplexity: 300.8357
# Epoch 88/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.5063 - perplexity: 299.5769
# Epoch 89/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4979 - perplexity: 295.8141
# Epoch 90/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4883 - perplexity: 293.5656
# Epoch 91/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4815 - perplexity: 291.3565
# Epoch 92/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4736 - perplexity: 288.5375
# Epoch 93/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4498 - perplexity: 283.8379
# Epoch 94/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4399 - perplexity: 281.9695
# Epoch 95/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4328 - perplexity: 278.8290
# Epoch 96/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4221 - perplexity: 276.2366
# Epoch 97/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4167 - perplexity: 274.9374
# Epoch 98/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4099 - perplexity: 273.7755
# Epoch 99/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.4015 - perplexity: 270.4181
# Epoch 100/100
# 2282/2282 [==============================] - 7s 3ms/step - loss: 7.3811 - perplexity: 265.7801
#
# --------evaluate---------
# 386/386 [==============================] - 1s 3ms/step - loss: 8.9400 - perplexity: 762.4026
# [8.940037727355957, 762.4026489257812]
#
# --------chart---------

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NLP/Project3
# 1/  2/  3/  dataset/  glove.6B.50d.txt  Project_3.ipynb  Project_show.ipynb

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#five gram

sequences_train = list()
for i in range(4, len(encoded_train)):
    sequence_train = encoded_train[i-3:i+2]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(4, len(encoded_test)):
    sequence_test = encoded_test[i-3:i+2]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57048
# Total Sequences test: 12344

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 5
# Max Sequences test Length: 5

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(50, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 50)                10050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15301)             780351
# =================================================================
# Total params: 20,790,451
# Trainable params: 790,401
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 29s 12ms/step - loss: 9.4518 - perplexity: 750.6510
# Epoch 2/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 9.0629 - perplexity: 654.7058
# Epoch 3/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.8114 - perplexity: 623.5755
# Epoch 4/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.7068 - perplexity: 619.3848
# Epoch 5/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.6468 - perplexity: 619.7909
# Epoch 6/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.6290 - perplexity: 622.3022
# Epoch 7/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5797 - perplexity: 620.0469
# Epoch 8/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5611 - perplexity: 619.6325
# Epoch 9/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5575 - perplexity: 624.5538
# Epoch 10/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.5624 - perplexity: 628.4260
# Epoch 11/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.5528 - perplexity: 629.5987
# Epoch 12/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5412 - perplexity: 629.6322
# Epoch 13/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5457 - perplexity: 631.7177
# Epoch 14/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5251 - perplexity: 630.4115
# Epoch 15/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5158 - perplexity: 628.7307
# Epoch 16/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5102 - perplexity: 627.4607
# Epoch 17/100
# 2282/2282 [==============================] - 29s 12ms/step - loss: 8.5151 - perplexity: 629.1311
# Epoch 18/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4975 - perplexity: 628.1775
# Epoch 19/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4933 - perplexity: 627.2757
# Epoch 20/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5001 - perplexity: 628.8436
# Epoch 21/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5002 - perplexity: 630.5910
# Epoch 22/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.4803 - perplexity: 626.6499
# Epoch 23/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4851 - perplexity: 631.2138
# Epoch 24/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4791 - perplexity: 628.5359
# Epoch 25/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4798 - perplexity: 629.5075
# Epoch 26/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4804 - perplexity: 630.9211
# Epoch 27/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4708 - perplexity: 627.8935
# Epoch 28/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4626 - perplexity: 628.8560
# Epoch 29/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4638 - perplexity: 628.9700
# Epoch 30/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4631 - perplexity: 630.3640
# Epoch 31/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4535 - perplexity: 627.8748
# Epoch 32/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4524 - perplexity: 630.1128
# Epoch 33/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4479 - perplexity: 628.5275
# Epoch 34/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4437 - perplexity: 626.5110
# Epoch 35/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4419 - perplexity: 629.3885
# Epoch 36/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4539 - perplexity: 630.8361
# Epoch 37/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4435 - perplexity: 631.6161
# Epoch 38/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4432 - perplexity: 627.9727
# Epoch 39/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4125 - perplexity: 622.8895
# Epoch 40/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4282 - perplexity: 625.2958
# Epoch 41/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4282 - perplexity: 625.9010
# Epoch 42/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4382 - perplexity: 627.2543
# Epoch 43/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4289 - perplexity: 628.6286
# Epoch 44/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4069 - perplexity: 623.6783
# Epoch 45/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4156 - perplexity: 625.2027
# Epoch 46/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4106 - perplexity: 621.3714
# Epoch 47/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4014 - perplexity: 622.0374
# Epoch 48/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4007 - perplexity: 618.1326
# Epoch 49/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3984 - perplexity: 621.6632
# Epoch 50/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3982 - perplexity: 615.1585
# Epoch 51/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3951 - perplexity: 618.0559
# Epoch 52/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3824 - perplexity: 614.0368
# Epoch 53/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3825 - perplexity: 616.8386
# Epoch 54/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3812 - perplexity: 616.0320
# Epoch 55/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3908 - perplexity: 615.7897
# Epoch 56/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3956 - perplexity: 619.5240
# Epoch 57/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3623 - perplexity: 610.1755
# Epoch 58/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3647 - perplexity: 612.7485
# Epoch 59/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3739 - perplexity: 612.1106
# Epoch 60/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3776 - perplexity: 614.3425
# Epoch 61/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3663 - perplexity: 611.2534
# Epoch 62/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3416 - perplexity: 603.9970
# Epoch 63/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3571 - perplexity: 604.3749
# Epoch 64/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3600 - perplexity: 604.7577
# Epoch 65/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3632 - perplexity: 606.5036
# Epoch 66/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3474 - perplexity: 603.3341
# Epoch 67/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3468 - perplexity: 601.0576
# Epoch 68/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3441 - perplexity: 600.6857
# Epoch 69/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3357 - perplexity: 599.3296
# Epoch 70/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3297 - perplexity: 596.7568
# Epoch 71/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3243 - perplexity: 593.1264
# Epoch 72/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3486 - perplexity: 600.1985
# Epoch 73/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3278 - perplexity: 593.6712
# Epoch 74/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3341 - perplexity: 594.2820
# Epoch 75/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3127 - perplexity: 590.5840
# Epoch 76/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3376 - perplexity: 596.2901
# Epoch 77/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3222 - perplexity: 592.7676
# Epoch 78/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3035 - perplexity: 588.3739
# Epoch 79/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3126 - perplexity: 588.7046
# Epoch 80/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3069 - perplexity: 585.5453
# Epoch 81/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3235 - perplexity: 589.5567
# Epoch 82/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.2951 - perplexity: 582.2174
# Epoch 83/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.3114 - perplexity: 586.0491
# Epoch 84/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.2922 - perplexity: 580.7615
# Epoch 85/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.2951 - perplexity: 582.4635
# Epoch 86/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2868 - perplexity: 581.3240
# Epoch 87/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2930 - perplexity: 580.5415
# Epoch 88/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3034 - perplexity: 581.0578
# Epoch 89/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2820 - perplexity: 578.7485
# Epoch 90/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2793 - perplexity: 576.9651
# Epoch 91/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2812 - perplexity: 575.1410
# Epoch 92/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2712 - perplexity: 574.0796
# Epoch 93/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2706 - perplexity: 571.7731
# Epoch 94/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.2683 - perplexity: 570.4842
# Epoch 95/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.2757 - perplexity: 573.9829
# Epoch 96/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2619 - perplexity: 570.0066
# Epoch 97/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2640 - perplexity: 566.9009
# Epoch 98/100
# 2282/2282 [==============================] - 31s 13ms/step - loss: 8.2494 - perplexity: 566.7756
# Epoch 99/100
# 2282/2282 [==============================] - 30s 13ms/step - loss: 8.2538 - perplexity: 564.6380
# Epoch 100/100
# 2282/2282 [==============================] - 31s 13ms/step - loss: 8.2549 - perplexity: 565.2275
#
# --------evaluate---------
# 386/386 [==============================] - 3s 7ms/step - loss: 8.6655 - perplexity: 567.8088
# [8.665534019470215, 567.8087768554688]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(100, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15301)             1545401
# =================================================================
# Total params: 21,565,551
# Trainable params: 1,565,501
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 9.3793 - perplexity: 734.9800
# Epoch 2/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.9087 - perplexity: 633.9142
# Epoch 3/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.6988 - perplexity: 620.5102
# Epoch 4/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.6380 - perplexity: 622.8795
# Epoch 5/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.5851 - perplexity: 623.4719
# Epoch 6/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.5654 - perplexity: 625.3350
# Epoch 7/100
# 2282/2282 [==============================] - 44s 19ms/step - loss: 8.5434 - perplexity: 627.3965
# Epoch 8/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.5393 - perplexity: 628.7427
# Epoch 9/100
# 2282/2282 [==============================] - 44s 19ms/step - loss: 8.5319 - perplexity: 632.6129
# Epoch 10/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.5180 - perplexity: 632.4263
# Epoch 11/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.5155 - perplexity: 631.1770
# Epoch 12/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.4845 - perplexity: 627.0589
# Epoch 13/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.4871 - perplexity: 626.3279
# Epoch 14/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4688 - perplexity: 623.6139
# Epoch 15/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4609 - perplexity: 622.8725
# Epoch 16/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4625 - perplexity: 623.7522
# Epoch 17/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4464 - perplexity: 622.2704
# Epoch 18/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4534 - perplexity: 623.5890
# Epoch 19/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4387 - perplexity: 622.1095
# Epoch 20/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4256 - perplexity: 620.6821
# Epoch 21/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.4174 - perplexity: 619.2665
# Epoch 22/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.4332 - perplexity: 620.7027
# Epoch 23/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.4089 - perplexity: 616.6136
# Epoch 24/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.3952 - perplexity: 613.8937
# Epoch 25/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.4093 - perplexity: 612.8367
# Epoch 26/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.3992 - perplexity: 611.6970
# Epoch 27/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.4080 - perplexity: 614.2905
# Epoch 28/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.3828 - perplexity: 610.3191
# Epoch 29/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3752 - perplexity: 606.6575
# Epoch 30/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.3639 - perplexity: 602.0348
# Epoch 31/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.3649 - perplexity: 603.9826
# Epoch 32/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.3594 - perplexity: 604.2486
# Epoch 33/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3569 - perplexity: 603.4758
# Epoch 34/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3570 - perplexity: 598.6565
# Epoch 35/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3426 - perplexity: 597.5648
# Epoch 36/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.3381 - perplexity: 593.9446
# Epoch 37/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3320 - perplexity: 593.7442
# Epoch 38/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3234 - perplexity: 590.5984
# Epoch 39/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.3234 - perplexity: 592.9223
# Epoch 40/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.3166 - perplexity: 584.8805
# Epoch 41/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.3199 - perplexity: 586.8737
# Epoch 42/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.3108 - perplexity: 585.0928
# Epoch 43/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.3010 - perplexity: 579.4789
# Epoch 44/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.2980 - perplexity: 581.5518
# Epoch 45/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2773 - perplexity: 575.1313
# Epoch 46/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2964 - perplexity: 577.2967
# Epoch 47/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2808 - perplexity: 574.6148
# Epoch 48/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2689 - perplexity: 570.5484
# Epoch 49/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2747 - perplexity: 569.7039
# Epoch 50/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2716 - perplexity: 566.9177
# Epoch 51/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2597 - perplexity: 566.1647
# Epoch 52/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2430 - perplexity: 559.9724
# Epoch 53/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.2463 - perplexity: 560.7390
# Epoch 54/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2398 - perplexity: 558.1013
# Epoch 55/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2358 - perplexity: 556.9885
# Epoch 56/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2292 - perplexity: 554.1236
# Epoch 57/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2168 - perplexity: 549.9098
# Epoch 58/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2062 - perplexity: 546.6222
# Epoch 59/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.2015 - perplexity: 544.1324
# Epoch 60/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1919 - perplexity: 541.8132
# Epoch 61/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1816 - perplexity: 539.3386
# Epoch 62/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1956 - perplexity: 539.7105
# Epoch 63/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1731 - perplexity: 533.2115
# Epoch 64/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1691 - perplexity: 530.3563
# Epoch 65/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1482 - perplexity: 526.9780
# Epoch 66/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1512 - perplexity: 526.4787
# Epoch 67/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1655 - perplexity: 527.7196
# Epoch 68/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1492 - perplexity: 524.6483
# Epoch 69/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.1417 - perplexity: 523.2711
# Epoch 70/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1309 - perplexity: 520.1016
# Epoch 71/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1255 - perplexity: 516.1133
# Epoch 72/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1160 - perplexity: 513.3631
# Epoch 73/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1241 - perplexity: 514.7514
# Epoch 74/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1063 - perplexity: 510.5811
# Epoch 75/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1114 - perplexity: 508.1337
# Epoch 76/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.0900 - perplexity: 502.6630
# Epoch 77/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.0850 - perplexity: 502.0960
# Epoch 78/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0833 - perplexity: 500.2445
# Epoch 79/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.0772 - perplexity: 497.3213
# Epoch 80/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0711 - perplexity: 494.9482
# Epoch 81/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0599 - perplexity: 494.1515
# Epoch 82/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0749 - perplexity: 492.7084
# Epoch 83/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0593 - perplexity: 489.4414
# Epoch 84/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0379 - perplexity: 482.2550
# Epoch 85/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0234 - perplexity: 479.2775
# Epoch 86/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.0172 - perplexity: 480.1498
# Epoch 87/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0221 - perplexity: 477.0659
# Epoch 88/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.0167 - perplexity: 476.4082
# Epoch 89/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0138 - perplexity: 472.3458
# Epoch 90/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.0098 - perplexity: 471.6988
# Epoch 91/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.0084 - perplexity: 470.2267
# Epoch 92/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 7.9857 - perplexity: 464.7557
# Epoch 93/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 7.9894 - perplexity: 462.6035
# Epoch 94/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 7.9817 - perplexity: 458.9256
# Epoch 95/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 7.9648 - perplexity: 456.4293
# Epoch 96/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 7.9665 - perplexity: 456.2294
# Epoch 97/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 7.9642 - perplexity: 455.2181
# Epoch 98/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 7.9469 - perplexity: 451.2411
# Epoch 99/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 7.9200 - perplexity: 442.9793
# Epoch 100/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 7.9312 - perplexity: 444.7544
#
# --------evaluate---------
# 386/386 [==============================] - 3s 8ms/step - loss: 8.7122 - perplexity: 591.7875
# [8.712240219116211, 591.7875366210938]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(150, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 150)               30150
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 150)               0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 150)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 15301)             2310451
# =================================================================
# Total params: 22,340,651
# Trainable params: 2,340,601
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 9.3382 - perplexity: 725.0545
# Epoch 2/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 8.8318 - perplexity: 627.6342
# Epoch 3/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.6700 - perplexity: 622.5616
# Epoch 4/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 8.6034 - perplexity: 624.8517
# Epoch 5/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 8.5698 - perplexity: 626.9414
# Epoch 6/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.5430 - perplexity: 627.5300
# Epoch 7/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.5340 - perplexity: 630.4314
# Epoch 8/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.5070 - perplexity: 626.9827
# Epoch 9/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.5005 - perplexity: 629.7943
# Epoch 10/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.4887 - perplexity: 628.1113
# Epoch 11/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.4823 - perplexity: 628.3222
# Epoch 12/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.4683 - perplexity: 627.4053
# Epoch 13/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.4642 - perplexity: 626.0075
# Epoch 14/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.4706 - perplexity: 627.3633
# Epoch 15/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.4361 - perplexity: 622.3981
# Epoch 16/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.4254 - perplexity: 617.7997
# Epoch 17/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.4128 - perplexity: 615.8621
# Epoch 18/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.4145 - perplexity: 617.0522
# Epoch 19/100
# 2282/2282 [==============================] - 56s 25ms/step - loss: 8.3970 - perplexity: 613.0302
# Epoch 20/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.3992 - perplexity: 612.1006
# Epoch 21/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.3894 - perplexity: 611.5256
# Epoch 22/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.3883 - perplexity: 610.3770
# Epoch 23/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.3736 - perplexity: 606.5296
# Epoch 24/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.3668 - perplexity: 604.7539
# Epoch 25/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.3588 - perplexity: 600.5125
# Epoch 26/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.3601 - perplexity: 600.1444
# Epoch 27/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.3492 - perplexity: 597.4169
# Epoch 28/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.3413 - perplexity: 593.4495
# Epoch 29/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.3147 - perplexity: 589.3337
# Epoch 30/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.3187 - perplexity: 589.0316
# Epoch 31/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2952 - perplexity: 584.3947
# Epoch 32/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2966 - perplexity: 581.6191
# Epoch 33/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2922 - perplexity: 581.9261
# Epoch 34/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.2948 - perplexity: 579.6529
# Epoch 35/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2806 - perplexity: 574.9535
# Epoch 36/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.2840 - perplexity: 574.7346
# Epoch 37/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2633 - perplexity: 567.2729
# Epoch 38/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.2582 - perplexity: 567.3294
# Epoch 39/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2612 - perplexity: 568.1157
# Epoch 40/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2279 - perplexity: 559.3791
# Epoch 41/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2336 - perplexity: 560.0627
# Epoch 42/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.2369 - perplexity: 555.6977
# Epoch 43/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2238 - perplexity: 556.0758
# Epoch 44/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.2061 - perplexity: 550.3690
# Epoch 45/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.2038 - perplexity: 546.1887
# Epoch 46/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.2012 - perplexity: 544.4330
# Epoch 47/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.1925 - perplexity: 543.8223
# Epoch 48/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.1780 - perplexity: 538.6062
# Epoch 49/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.1719 - perplexity: 534.4824
# Epoch 50/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.1710 - perplexity: 532.1671
# Epoch 51/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.1332 - perplexity: 527.8294
# Epoch 52/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.1455 - perplexity: 524.9769
# Epoch 53/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.1365 - perplexity: 523.1104
# Epoch 54/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.1283 - perplexity: 519.1630
# Epoch 55/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.1134 - perplexity: 513.8134
# Epoch 56/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.0975 - perplexity: 509.8144
# Epoch 57/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.0986 - perplexity: 508.4746
# Epoch 58/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 8.0873 - perplexity: 505.3148
# Epoch 59/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.0782 - perplexity: 500.9701
# Epoch 60/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.0686 - perplexity: 496.0092
# Epoch 61/100
# 2282/2282 [==============================] - 58s 25ms/step - loss: 8.0490 - perplexity: 492.4951
# Epoch 62/100
# 2282/2282 [==============================] - 57s 25ms/step - loss: 8.0585 - perplexity: 492.6000
# Epoch 63/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.0513 - perplexity: 489.6900
# Epoch 64/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 8.0340 - perplexity: 485.2473
# Epoch 65/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.0069 - perplexity: 479.8047
# Epoch 66/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 8.0119 - perplexity: 477.5363
# Epoch 67/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9910 - perplexity: 472.5851
# Epoch 68/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9920 - perplexity: 469.5664
# Epoch 69/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9829 - perplexity: 467.7045
# Epoch 70/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9874 - perplexity: 467.7468
# Epoch 71/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.9675 - perplexity: 460.6540
# Epoch 72/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9631 - perplexity: 460.4407
# Epoch 73/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9500 - perplexity: 455.3354
# Epoch 74/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9359 - perplexity: 449.4003
# Epoch 75/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9241 - perplexity: 448.4182
# Epoch 76/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9203 - perplexity: 445.6962
# Epoch 77/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9144 - perplexity: 441.3091
# Epoch 78/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.9035 - perplexity: 439.3119
# Epoch 79/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.8962 - perplexity: 433.7940
# Epoch 80/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.8959 - perplexity: 433.0365
# Epoch 81/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.8822 - perplexity: 430.1483
# Epoch 82/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.8726 - perplexity: 426.9681
# Epoch 83/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.8644 - perplexity: 424.6377
# Epoch 84/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.8507 - perplexity: 418.5214
# Epoch 85/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.8347 - perplexity: 414.6044
# Epoch 86/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.8252 - perplexity: 411.4232
# Epoch 87/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.8277 - perplexity: 409.6648
# Epoch 88/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.8060 - perplexity: 405.9074
# Epoch 89/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.7965 - perplexity: 401.3402
# Epoch 90/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.7907 - perplexity: 398.9323
# Epoch 91/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.7791 - perplexity: 394.5358
# Epoch 92/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.7718 - perplexity: 392.0293
# Epoch 93/100
# 2282/2282 [==============================] - 56s 24ms/step - loss: 7.7513 - perplexity: 388.1052
# Epoch 94/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.7386 - perplexity: 383.4438
# Epoch 95/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 7.7386 - perplexity: 382.1866
# Epoch 96/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 7.7246 - perplexity: 378.7454
# Epoch 97/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.7091 - perplexity: 375.3159
# Epoch 98/100
# 2282/2282 [==============================] - 55s 24ms/step - loss: 7.6968 - perplexity: 372.9526
# Epoch 99/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 7.6891 - perplexity: 368.4361
# Epoch 100/100
# 2282/2282 [==============================] - 54s 24ms/step - loss: 7.6969 - perplexity: 368.9561
#
# --------evaluate---------
# 386/386 [==============================] - 4s 11ms/step - loss: 8.7611 - perplexity: 616.1201
# [8.76106071472168, 616.1201171875]
#
# --------chart---------

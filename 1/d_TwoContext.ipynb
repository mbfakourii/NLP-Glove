# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NLP/Project3
# 1/  2/  3/  dataset/  glove.6B.50d.txt  Project_3.ipynb  Project_show.ipynb

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#Three gram

sequences_train = list()
for i in range(2, len(encoded_train)):
    sequence_train = encoded_train[i-2:i+1]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(2, len(encoded_test)):
    sequence_test = encoded_test[i-2:i+1]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57050
# Total Sequences test: 12346

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 3
# Max Sequences test Length: 3

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras (see above)
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(Flatten())
model.add(Dense(35, activation='sigmoid'))
model.add(Dropout(0.1))
model.add(Flatten())
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2, 50)             20000050
# _________________________________________________________________
# flatten (Flatten)            (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 35)                3535
# _________________________________________________________________
# dropout (Dropout)            (None, 35)                0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 35)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15301)             550836
# =================================================================
# Total params: 20,554,421
# Trainable params: 554,371
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None

# %%
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)
# Out:
# Epoch 1/100
# 2282/2282 [==============================] - 24s 10ms/step - loss: 9.4906 - perplexity: 758.7431
# Epoch 2/100
# 2282/2282 [==============================] - 24s 10ms/step - loss: 9.1909 - perplexity: 683.0336
# Epoch 3/100
# 2282/2282 [==============================] - 24s 11ms/step - loss: 8.9577 - perplexity: 637.5202
# Epoch 4/100
# 2282/2282 [==============================] - 25s 11ms/step - loss: 8.8187 - perplexity: 623.1413
# Epoch 5/100
# 2282/2282 [==============================] - 26s 11ms/step - loss: 8.7255 - perplexity: 618.2575
# Epoch 6/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.6634 - perplexity: 612.7286
# Epoch 7/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.6401 - perplexity: 616.1352
# Epoch 8/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.6131 - perplexity: 617.9818
# Epoch 9/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.6136 - perplexity: 620.8257
# Epoch 10/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5974 - perplexity: 625.1530
# Epoch 11/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.5766 - perplexity: 623.0198
# Epoch 12/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5593 - perplexity: 623.5295
# Epoch 13/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5462 - perplexity: 624.7287
# Epoch 14/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5490 - perplexity: 626.8796
# Epoch 15/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.5562 - perplexity: 630.0972
# Epoch 16/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.5361 - perplexity: 627.5034
# Epoch 17/100
# 2282/2282 [==============================] - 31s 14ms/step - loss: 8.5303 - perplexity: 627.2467
# Epoch 18/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5284 - perplexity: 628.7570
# Epoch 19/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5249 - perplexity: 630.6014
# Epoch 20/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5203 - perplexity: 628.9873
# Epoch 21/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5125 - perplexity: 632.3370
# Epoch 22/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5180 - perplexity: 631.3795
# Epoch 23/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5112 - perplexity: 632.2943
# Epoch 24/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5098 - perplexity: 633.5774
# Epoch 25/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4965 - perplexity: 629.2593
# Epoch 26/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4978 - perplexity: 634.4160
# Epoch 27/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5084 - perplexity: 635.7707
# Epoch 28/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5018 - perplexity: 637.7089
# Epoch 29/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.5002 - perplexity: 634.9174
# Epoch 30/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4770 - perplexity: 633.1750
# Epoch 31/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4864 - perplexity: 631.7887
# Epoch 32/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4922 - perplexity: 635.3055
# Epoch 33/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4848 - perplexity: 634.1852
# Epoch 34/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4894 - perplexity: 635.5219
# Epoch 35/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4697 - perplexity: 631.4429
# Epoch 36/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4731 - perplexity: 631.9041
# Epoch 37/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4734 - perplexity: 631.2381
# Epoch 38/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4891 - perplexity: 638.3800
# Epoch 39/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4742 - perplexity: 634.0619
# Epoch 40/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4765 - perplexity: 636.3037
# Epoch 41/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4673 - perplexity: 634.6030
# Epoch 42/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4655 - perplexity: 632.3650
# Epoch 43/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4735 - perplexity: 636.4099
# Epoch 44/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4594 - perplexity: 632.4319
# Epoch 45/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4653 - perplexity: 632.9114
# Epoch 46/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4426 - perplexity: 629.9384
# Epoch 47/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4647 - perplexity: 634.0701
# Epoch 48/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4462 - perplexity: 629.8748
# Epoch 49/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4471 - perplexity: 631.9349
# Epoch 50/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4582 - perplexity: 634.5981
# Epoch 51/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4468 - perplexity: 632.7573
# Epoch 52/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4507 - perplexity: 634.8626
# Epoch 53/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4369 - perplexity: 632.4817
# Epoch 54/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4451 - perplexity: 632.2082
# Epoch 55/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4355 - perplexity: 631.1477
# Epoch 56/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4559 - perplexity: 632.4782
# Epoch 57/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4396 - perplexity: 631.5187
# Epoch 58/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4288 - perplexity: 628.1493
# Epoch 59/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4256 - perplexity: 626.7326
# Epoch 60/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4277 - perplexity: 624.7588
# Epoch 61/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4365 - perplexity: 631.7136
# Epoch 62/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4352 - perplexity: 629.2849
# Epoch 63/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4347 - perplexity: 630.4876
# Epoch 64/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4236 - perplexity: 627.2954
# Epoch 65/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4367 - perplexity: 628.0579
# Epoch 66/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4337 - perplexity: 628.7699
# Epoch 67/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4342 - perplexity: 629.6474
# Epoch 68/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4256 - perplexity: 625.9474
# Epoch 69/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4020 - perplexity: 619.9688
# Epoch 70/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4256 - perplexity: 623.7391
# Epoch 71/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4047 - perplexity: 622.1551
# Epoch 72/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4117 - perplexity: 624.1583
# Epoch 73/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4043 - perplexity: 620.8281
# Epoch 74/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4158 - perplexity: 624.0471
# Epoch 75/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3988 - perplexity: 618.7956
# Epoch 76/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4066 - perplexity: 619.9521
# Epoch 77/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4115 - perplexity: 620.6293
# Epoch 78/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4017 - perplexity: 621.1730
# Epoch 79/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.4065 - perplexity: 621.7142
# Epoch 80/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.4065 - perplexity: 618.2663
# Epoch 81/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.3957 - perplexity: 618.2940
# Epoch 82/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.4019 - perplexity: 617.5680
# Epoch 83/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.4045 - perplexity: 618.5994
# Epoch 84/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3979 - perplexity: 616.6593
# Epoch 85/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3986 - perplexity: 617.8573
# Epoch 86/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3840 - perplexity: 613.4749
# Epoch 87/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.4019 - perplexity: 618.8800
# Epoch 88/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3821 - perplexity: 614.6860
# Epoch 89/100
# 2282/2282 [==============================] - 31s 14ms/step - loss: 8.3860 - perplexity: 612.7313
# Epoch 90/100
# 2282/2282 [==============================] - 29s 13ms/step - loss: 8.3891 - perplexity: 614.3136
# Epoch 91/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3971 - perplexity: 614.8346
# Epoch 92/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3937 - perplexity: 614.8242
# Epoch 93/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3933 - perplexity: 616.0428
# Epoch 94/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.3723 - perplexity: 611.4038
# Epoch 95/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.3757 - perplexity: 608.5980
# Epoch 96/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3638 - perplexity: 607.5745
# Epoch 97/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3790 - perplexity: 607.0644
# Epoch 98/100
# 2282/2282 [==============================] - 28s 12ms/step - loss: 8.3575 - perplexity: 602.4513
# Epoch 99/100
# 2282/2282 [==============================] - 27s 12ms/step - loss: 8.3733 - perplexity: 608.8522
# Epoch 100/100
# 2282/2282 [==============================] - 29s 12ms/step - loss: 8.3574 - perplexity: 602.9591

# %%
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])

# %%
print(model.evaluate(X_test,y_test))
# Out:
# 386/386 [==============================] - 3s 8ms/step - loss: 8.6328 - perplexity: 556.2695
# [8.632795333862305, 556.26953125]

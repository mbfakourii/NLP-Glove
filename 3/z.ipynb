# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NLP/Project3
# 1/  3/        glove.6B.50d.txt  Project_show.ipynb
# 2/  dataset/  Project_3.ipynb   sample_3.ipynb

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#five gram

sequences_train = list()
for i in range(4, len(encoded_train)):
    sequence_train = encoded_train[i-3:i+2]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(4, len(encoded_test)):
    sequence_test = encoded_test[i-3:i+2]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57048
# Total Sequences test: 12344

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 5
# Max Sequences test Length: 5

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras (see above)
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(50))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# lstm (LSTM)                  (None, 50)                20200
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 15301)             780351
# =================================================================
# Total params: 20,800,601
# Trainable params: 800,551
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 14s 5ms/step - loss: 9.6057 - perplexity: 783.4779
# Epoch 2/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 9.3916 - perplexity: 741.2758
# Epoch 3/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 9.1449 - perplexity: 672.2089
# Epoch 4/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.8635 - perplexity: 632.6994
# Epoch 5/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.7414 - perplexity: 623.9763
# Epoch 6/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.6714 - perplexity: 621.4321
# Epoch 7/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.6538 - perplexity: 627.7149
# Epoch 8/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.6312 - perplexity: 633.7135
# Epoch 9/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.6002 - perplexity: 632.0220
# Epoch 10/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.5999 - perplexity: 641.1976
# Epoch 11/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5779 - perplexity: 638.9582
# Epoch 12/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5787 - perplexity: 642.4273
# Epoch 13/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5713 - perplexity: 645.2143
# Epoch 14/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5570 - perplexity: 641.4547
# Epoch 15/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5437 - perplexity: 639.3298
# Epoch 16/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.5413 - perplexity: 640.3643
# Epoch 17/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5442 - perplexity: 638.5492
# Epoch 18/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5199 - perplexity: 638.4296
# Epoch 19/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5334 - perplexity: 645.6042
# Epoch 20/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5210 - perplexity: 640.5922
# Epoch 21/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5228 - perplexity: 639.3262
# Epoch 22/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5049 - perplexity: 638.1331
# Epoch 23/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4952 - perplexity: 636.8226
# Epoch 24/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4796 - perplexity: 633.0659
# Epoch 25/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4883 - perplexity: 637.1378
# Epoch 26/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4808 - perplexity: 635.7111
# Epoch 27/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4778 - perplexity: 637.9157
# Epoch 28/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4690 - perplexity: 633.1219
# Epoch 29/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4698 - perplexity: 631.2463
# Epoch 30/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4545 - perplexity: 632.7087
# Epoch 31/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4466 - perplexity: 631.4924
# Epoch 32/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4349 - perplexity: 627.5459
# Epoch 33/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4433 - perplexity: 630.2261
# Epoch 34/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4311 - perplexity: 627.1844
# Epoch 35/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4234 - perplexity: 627.9880
# Epoch 36/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4176 - perplexity: 622.5424
# Epoch 37/100
# 2282/2282 [==============================] - 13s 6ms/step - loss: 8.4240 - perplexity: 627.9155
# Epoch 38/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4131 - perplexity: 622.8508
# Epoch 39/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4049 - perplexity: 622.8942
# Epoch 40/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4077 - perplexity: 624.6116
# Epoch 41/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4107 - perplexity: 626.6337
# Epoch 42/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3975 - perplexity: 621.1893
# Epoch 43/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3982 - perplexity: 621.0530
# Epoch 44/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3927 - perplexity: 620.0968
# Epoch 45/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3846 - perplexity: 618.6280
# Epoch 46/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3755 - perplexity: 616.1820
# Epoch 47/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3885 - perplexity: 616.0752
# Epoch 48/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3905 - perplexity: 614.4212
# Epoch 49/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3660 - perplexity: 611.7603
# Epoch 50/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3647 - perplexity: 609.9778
# Epoch 51/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3709 - perplexity: 612.2654
# Epoch 52/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3663 - perplexity: 608.5647
# Epoch 53/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3417 - perplexity: 604.1626
# Epoch 54/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3338 - perplexity: 603.2736
# Epoch 55/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3454 - perplexity: 600.8803
# Epoch 56/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3448 - perplexity: 600.5578
# Epoch 57/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3192 - perplexity: 597.0686
# Epoch 58/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3291 - perplexity: 596.7161
# Epoch 59/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3105 - perplexity: 593.7936
# Epoch 60/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3271 - perplexity: 593.3239
# Epoch 61/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3089 - perplexity: 591.7175
# Epoch 62/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3080 - perplexity: 588.7858
# Epoch 63/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3193 - perplexity: 588.7190
# Epoch 64/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3192 - perplexity: 589.7093
# Epoch 65/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3014 - perplexity: 586.2003
# Epoch 66/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3086 - perplexity: 587.0546
# Epoch 67/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3029 - perplexity: 584.1602
# Epoch 68/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2914 - perplexity: 582.7589
# Epoch 69/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2915 - perplexity: 580.6811
# Epoch 70/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.2738 - perplexity: 572.5618
# Epoch 71/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2807 - perplexity: 574.5631
# Epoch 72/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2815 - perplexity: 574.6567
# Epoch 73/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2706 - perplexity: 575.0050
# Epoch 74/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2547 - perplexity: 568.1803
# Epoch 75/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2649 - perplexity: 569.2691
# Epoch 76/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2668 - perplexity: 568.2216
# Epoch 77/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2617 - perplexity: 570.2437
# Epoch 78/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2544 - perplexity: 563.8668
# Epoch 79/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2435 - perplexity: 560.6209
# Epoch 80/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2348 - perplexity: 555.8440
# Epoch 81/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2345 - perplexity: 558.0709
# Epoch 82/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2326 - perplexity: 557.5536
# Epoch 83/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2245 - perplexity: 555.9051
# Epoch 84/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2215 - perplexity: 552.3696
# Epoch 85/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2215 - perplexity: 553.5977
# Epoch 86/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2193 - perplexity: 548.0247
# Epoch 87/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2114 - perplexity: 547.0611
# Epoch 88/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2118 - perplexity: 545.3680
# Epoch 89/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2031 - perplexity: 541.3525
# Epoch 90/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2172 - perplexity: 544.4592
# Epoch 91/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1881 - perplexity: 537.3572
# Epoch 92/100
# 2282/2282 [==============================] - 13s 6ms/step - loss: 8.1907 - perplexity: 538.6471
# Epoch 93/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2016 - perplexity: 536.2966
# Epoch 94/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1907 - perplexity: 534.8130
# Epoch 95/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1799 - perplexity: 531.8100
# Epoch 96/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1747 - perplexity: 526.8899
# Epoch 97/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.1908 - perplexity: 531.7630
# Epoch 98/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1676 - perplexity: 526.6509
# Epoch 99/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1572 - perplexity: 524.3673
# Epoch 100/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1579 - perplexity: 523.7294
#
# --------evaluate---------
# 386/386 [==============================] - 2s 4ms/step - loss: 8.7125 - perplexity: 590.3358
# [8.712544441223145, 590.3358154296875]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(100))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15301)             1545401
# =================================================================
# Total params: 21,605,851
# Trainable params: 1,605,801
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 13s 5ms/step - loss: 9.5942 - perplexity: 780.6418
# Epoch 2/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 9.3254 - perplexity: 723.9355
# Epoch 3/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.9251 - perplexity: 641.3890
# Epoch 4/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.7127 - perplexity: 628.7847
# Epoch 5/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.6462 - perplexity: 630.8429
# Epoch 6/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.6123 - perplexity: 639.9426
# Epoch 7/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5916 - perplexity: 642.4192
# Epoch 8/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5711 - perplexity: 644.6283
# Epoch 9/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5531 - perplexity: 646.0143
# Epoch 10/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5417 - perplexity: 642.7911
# Epoch 11/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5321 - perplexity: 645.4645
# Epoch 12/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5130 - perplexity: 639.4513
# Epoch 13/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5107 - perplexity: 640.8062
# Epoch 14/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4969 - perplexity: 639.9433
# Epoch 15/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4658 - perplexity: 633.4812
# Epoch 16/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4617 - perplexity: 633.3147
# Epoch 17/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4629 - perplexity: 638.5097
# Epoch 18/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4516 - perplexity: 632.8085
# Epoch 19/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.4450 - perplexity: 629.3035
# Epoch 20/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4277 - perplexity: 628.3926
# Epoch 21/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4187 - perplexity: 626.6143
# Epoch 22/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4320 - perplexity: 631.1811
# Epoch 23/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4206 - perplexity: 625.2918
# Epoch 24/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.4187 - perplexity: 624.6665
# Epoch 25/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3964 - perplexity: 621.7508
# Epoch 26/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4015 - perplexity: 619.6793
# Epoch 27/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3843 - perplexity: 616.0973
# Epoch 28/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3835 - perplexity: 613.0345
# Epoch 29/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3674 - perplexity: 611.7499
# Epoch 30/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3693 - perplexity: 610.3832
# Epoch 31/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3509 - perplexity: 607.2909
# Epoch 32/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3602 - perplexity: 603.9164
# Epoch 33/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3409 - perplexity: 599.0531
# Epoch 34/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3366 - perplexity: 597.0716
# Epoch 35/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3248 - perplexity: 592.8995
# Epoch 36/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3119 - perplexity: 591.1693
# Epoch 37/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3084 - perplexity: 588.3416
# Epoch 38/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3097 - perplexity: 586.3976
# Epoch 39/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2995 - perplexity: 580.3999
# Epoch 40/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2926 - perplexity: 578.0638
# Epoch 41/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2781 - perplexity: 576.4295
# Epoch 42/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2739 - perplexity: 571.6753
# Epoch 43/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2586 - perplexity: 566.5898
# Epoch 44/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2574 - perplexity: 566.3361
# Epoch 45/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2522 - perplexity: 564.1454
# Epoch 46/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2648 - perplexity: 563.2243
# Epoch 47/100
# 2282/2282 [==============================] - 13s 5ms/step - loss: 8.2377 - perplexity: 558.2182
# Epoch 48/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2320 - perplexity: 553.3719
# Epoch 49/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2304 - perplexity: 552.8974
# Epoch 50/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2254 - perplexity: 548.6115
# Epoch 51/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.2232 - perplexity: 546.6397
# Epoch 52/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2018 - perplexity: 542.1988
# Epoch 53/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2082 - perplexity: 543.6515
# Epoch 54/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2003 - perplexity: 539.3435
# Epoch 55/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1790 - perplexity: 532.4046
# Epoch 56/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1762 - perplexity: 530.4408
# Epoch 57/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1682 - perplexity: 527.2581
# Epoch 58/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1615 - perplexity: 523.5369
# Epoch 59/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1657 - perplexity: 523.3159
# Epoch 60/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1476 - perplexity: 521.0024
# Epoch 61/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1433 - perplexity: 515.3924
# Epoch 62/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1312 - perplexity: 513.1802
# Epoch 63/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1412 - perplexity: 512.8994
# Epoch 64/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1184 - perplexity: 505.9665
# Epoch 65/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1099 - perplexity: 501.7660
# Epoch 66/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1114 - perplexity: 502.5795
# Epoch 67/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0877 - perplexity: 494.4205
# Epoch 68/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0990 - perplexity: 493.0980
# Epoch 69/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0900 - perplexity: 491.1790
# Epoch 70/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0777 - perplexity: 485.7750
# Epoch 71/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0956 - perplexity: 489.0825
# Epoch 72/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0556 - perplexity: 479.7935
# Epoch 73/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0539 - perplexity: 477.2104
# Epoch 74/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0430 - perplexity: 476.8431
# Epoch 75/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0338 - perplexity: 469.8317
# Epoch 76/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0339 - perplexity: 468.2798
# Epoch 77/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0259 - perplexity: 464.3982
# Epoch 78/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0004 - perplexity: 459.5181
# Epoch 79/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0085 - perplexity: 457.9834
# Epoch 80/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0106 - perplexity: 456.3309
# Epoch 81/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0003 - perplexity: 451.0733
# Epoch 82/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9890 - perplexity: 450.8303
# Epoch 83/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9806 - perplexity: 449.3622
# Epoch 84/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9645 - perplexity: 441.7785
# Epoch 85/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9583 - perplexity: 437.2975
# Epoch 86/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9492 - perplexity: 437.5018
# Epoch 87/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9432 - perplexity: 432.0258
# Epoch 88/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9343 - perplexity: 429.8418
# Epoch 89/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9295 - perplexity: 427.8803
# Epoch 90/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9249 - perplexity: 424.8367
# Epoch 91/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9200 - perplexity: 421.3494
# Epoch 92/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9106 - perplexity: 420.7206
# Epoch 93/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9037 - perplexity: 418.5246
# Epoch 94/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8997 - perplexity: 413.2817
# Epoch 95/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8918 - perplexity: 411.5627
# Epoch 96/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8704 - perplexity: 406.7458
# Epoch 97/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8643 - perplexity: 404.4717
# Epoch 98/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8586 - perplexity: 400.8810
# Epoch 99/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8524 - perplexity: 398.4087
# Epoch 100/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8413 - perplexity: 393.9825
#
# --------evaluate---------
# 386/386 [==============================] - 2s 4ms/step - loss: 8.7876 - perplexity: 650.9092
# [8.787636756896973, 650.9092407226562]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(150))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 150)               120600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15301)             2310451
# =================================================================
# Total params: 22,431,101
# Trainable params: 2,431,051
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 14s 5ms/step - loss: 9.5919 - perplexity: 780.4068
# Epoch 2/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 9.2811 - perplexity: 712.3192
# Epoch 3/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.8539 - perplexity: 637.7193
# Epoch 4/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.6766 - perplexity: 636.8208
# Epoch 5/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.6152 - perplexity: 641.7178
# Epoch 6/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5839 - perplexity: 644.3120
# Epoch 7/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5744 - perplexity: 647.6451
# Epoch 8/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5451 - perplexity: 648.4638
# Epoch 9/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5393 - perplexity: 647.6133
# Epoch 10/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5283 - perplexity: 645.7825
# Epoch 11/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5048 - perplexity: 643.0075
# Epoch 12/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.4872 - perplexity: 640.6608
# Epoch 13/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4707 - perplexity: 636.2848
# Epoch 14/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4779 - perplexity: 637.7265
# Epoch 15/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4681 - perplexity: 637.4841
# Epoch 16/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4531 - perplexity: 632.6937
# Epoch 17/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4260 - perplexity: 626.2961
# Epoch 18/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4254 - perplexity: 626.8025
# Epoch 19/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4180 - perplexity: 626.6582
# Epoch 20/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3987 - perplexity: 624.5545
# Epoch 21/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3927 - perplexity: 620.9802
# Epoch 22/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3997 - perplexity: 618.6391
# Epoch 23/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3792 - perplexity: 615.2348
# Epoch 24/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3711 - perplexity: 612.9357
# Epoch 25/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3589 - perplexity: 609.1077
# Epoch 26/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3511 - perplexity: 603.4902
# Epoch 27/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3279 - perplexity: 595.3216
# Epoch 28/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3363 - perplexity: 595.5520
# Epoch 29/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3277 - perplexity: 594.0691
# Epoch 30/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3297 - perplexity: 590.5242
# Epoch 31/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2975 - perplexity: 583.6029
# Epoch 32/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.2898 - perplexity: 578.8084
# Epoch 33/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2786 - perplexity: 575.8225
# Epoch 34/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2681 - perplexity: 573.5508
# Epoch 35/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2570 - perplexity: 568.3558
# Epoch 36/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2610 - perplexity: 563.0007
# Epoch 37/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2182 - perplexity: 556.7844
# Epoch 38/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2185 - perplexity: 551.4144
# Epoch 39/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2375 - perplexity: 551.7782
# Epoch 40/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.2109 - perplexity: 544.8811
# Epoch 41/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.2005 - perplexity: 541.5885
# Epoch 42/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1905 - perplexity: 537.4905
# Epoch 43/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1752 - perplexity: 533.8815
# Epoch 44/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1759 - perplexity: 526.6624
# Epoch 45/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1480 - perplexity: 519.3955
# Epoch 46/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1342 - perplexity: 515.5150
# Epoch 47/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1354 - perplexity: 510.6148
# Epoch 48/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1346 - perplexity: 510.3779
# Epoch 49/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1198 - perplexity: 505.8351
# Epoch 50/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.1046 - perplexity: 500.4102
# Epoch 51/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0874 - perplexity: 494.1751
# Epoch 52/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0815 - perplexity: 491.0658
# Epoch 53/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0771 - perplexity: 488.0131
# Epoch 54/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0579 - perplexity: 482.6531
# Epoch 55/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0517 - perplexity: 476.9343
# Epoch 56/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0340 - perplexity: 471.8906
# Epoch 57/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.0089 - perplexity: 465.2062
# Epoch 58/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.0263 - perplexity: 464.6304
# Epoch 59/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9942 - perplexity: 457.3973
# Epoch 60/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9868 - perplexity: 454.4443
# Epoch 61/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9802 - perplexity: 449.7703
# Epoch 62/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.9674 - perplexity: 447.6707
# Epoch 63/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9534 - perplexity: 439.4766
# Epoch 64/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9373 - perplexity: 433.6431
# Epoch 65/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9162 - perplexity: 428.6689
# Epoch 66/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9319 - perplexity: 430.2630
# Epoch 67/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.9027 - perplexity: 422.8666
# Epoch 68/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.8899 - perplexity: 417.1236
# Epoch 69/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8884 - perplexity: 413.9099
# Epoch 70/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8629 - perplexity: 409.2109
# Epoch 71/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8633 - perplexity: 406.8018
# Epoch 72/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.8469 - perplexity: 401.8368
# Epoch 73/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8341 - perplexity: 396.6728
# Epoch 74/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8259 - perplexity: 393.6206
# Epoch 75/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8119 - perplexity: 388.8668
# Epoch 76/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.8087 - perplexity: 383.8595
# Epoch 77/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.7936 - perplexity: 381.3788
# Epoch 78/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.7800 - perplexity: 378.1046
# Epoch 79/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.7636 - perplexity: 372.8784
# Epoch 80/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.7650 - perplexity: 370.8650
# Epoch 81/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.7497 - perplexity: 366.8133
# Epoch 82/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.7371 - perplexity: 363.0671
# Epoch 83/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.7268 - perplexity: 359.5381
# Epoch 84/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.7045 - perplexity: 353.1810
# Epoch 85/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.7011 - perplexity: 351.3846
# Epoch 86/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 7.6979 - perplexity: 347.6742
# Epoch 87/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6772 - perplexity: 343.2264
# Epoch 88/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6639 - perplexity: 340.0108
# Epoch 89/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6660 - perplexity: 338.8218
# Epoch 90/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6297 - perplexity: 332.9336
# Epoch 91/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6203 - perplexity: 327.8797
# Epoch 92/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6196 - perplexity: 326.4835
# Epoch 93/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.6136 - perplexity: 323.9397
# Epoch 94/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5884 - perplexity: 317.8724
# Epoch 95/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5731 - perplexity: 314.4768
# Epoch 96/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5722 - perplexity: 312.5231
# Epoch 97/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5722 - perplexity: 309.7796
# Epoch 98/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5442 - perplexity: 306.4101
# Epoch 99/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5292 - perplexity: 302.1248
# Epoch 100/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 7.5403 - perplexity: 302.4000
#
# --------evaluate---------
# 386/386 [==============================] - 2s 4ms/step - loss: 8.8779 - perplexity: 722.3127
# [8.877877235412598, 722.3126831054688]
#
# --------chart---------

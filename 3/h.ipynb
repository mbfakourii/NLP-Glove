# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NLP/Project3
# 1/  3/        glove.6B.50d.txt  Project_show.ipynb
# 2/  dataset/  Project_3.ipynb   sample_3.ipynb

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#five gram

sequences_train = list()
for i in range(4, len(encoded_train)):
    sequence_train = encoded_train[i-3:i+2]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(4, len(encoded_test)):
    sequence_test = encoded_test[i-3:i+2]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57048
# Total Sequences test: 12344

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 5
# Max Sequences test Length: 5

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras (see above)
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(35))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.01,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# lstm (LSTM)                  (None, 35)                12040
# _________________________________________________________________
# dropout (Dropout)            (None, 35)                0
# _________________________________________________________________
# dense (Dense)                (None, 15301)             550836
# =================================================================
# Total params: 20,562,926
# Trainable params: 562,876
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 44s 18ms/step - loss: 9.6238 - perplexity: 789.7085
# Epoch 2/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 9.5609 - perplexity: 767.6199
# Epoch 3/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 9.4411 - perplexity: 748.3632
# Epoch 4/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 9.3554 - perplexity: 731.9715
# Epoch 5/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 9.2714 - perplexity: 701.8260
# Epoch 6/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 9.1348 - perplexity: 666.3793
# Epoch 7/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 9.0112 - perplexity: 644.6099
# Epoch 8/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.9156 - perplexity: 631.8735
# Epoch 9/100
# 2282/2282 [==============================] - 48s 21ms/step - loss: 8.8423 - perplexity: 626.2034
# Epoch 10/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.8066 - perplexity: 623.4947
# Epoch 11/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.7683 - perplexity: 622.6507
# Epoch 12/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 8.7258 - perplexity: 619.5432
# Epoch 13/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.6980 - perplexity: 619.3284
# Epoch 14/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.6742 - perplexity: 618.5203
# Epoch 15/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.6734 - perplexity: 622.6111
# Epoch 16/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.6535 - perplexity: 624.3284
# Epoch 17/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.6392 - perplexity: 622.9154
# Epoch 18/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.6363 - perplexity: 625.2632
# Epoch 19/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.6125 - perplexity: 623.1739
# Epoch 20/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.6061 - perplexity: 626.3463
# Epoch 21/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.6135 - perplexity: 630.0383
# Epoch 22/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5966 - perplexity: 628.5117
# Epoch 23/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5887 - perplexity: 629.4836
# Epoch 24/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5836 - perplexity: 628.0235
# Epoch 25/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5924 - perplexity: 633.1473
# Epoch 26/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5954 - perplexity: 636.8347
# Epoch 27/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5847 - perplexity: 633.4299
# Epoch 28/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5759 - perplexity: 634.8056
# Epoch 29/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5792 - perplexity: 634.5364
# Epoch 30/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5714 - perplexity: 635.0248
# Epoch 31/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5481 - perplexity: 633.2611
# Epoch 32/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5472 - perplexity: 632.3897
# Epoch 33/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5597 - perplexity: 634.9571
# Epoch 34/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5500 - perplexity: 635.0982
# Epoch 35/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5466 - perplexity: 635.0094
# Epoch 36/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5442 - perplexity: 634.8980
# Epoch 37/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5527 - perplexity: 638.6308
# Epoch 38/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5240 - perplexity: 632.4263
# Epoch 39/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5250 - perplexity: 633.0981
# Epoch 40/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 8.5412 - perplexity: 636.1931
# Epoch 41/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5279 - perplexity: 636.9411
# Epoch 42/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5237 - perplexity: 634.7803
# Epoch 43/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5252 - perplexity: 634.2422
# Epoch 44/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5166 - perplexity: 634.7932
# Epoch 45/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.5152 - perplexity: 633.7461
# Epoch 46/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5125 - perplexity: 635.6121
# Epoch 47/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 8.5079 - perplexity: 629.9881
# Epoch 48/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5227 - perplexity: 638.4085
# Epoch 49/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5032 - perplexity: 632.8597
# Epoch 50/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4973 - perplexity: 633.0434
# Epoch 51/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5001 - perplexity: 636.0598
# Epoch 52/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.5041 - perplexity: 636.7433
# Epoch 53/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4976 - perplexity: 633.5961
# Epoch 54/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4961 - perplexity: 634.4765
# Epoch 55/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5044 - perplexity: 636.7024
# Epoch 56/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.4854 - perplexity: 633.5152
# Epoch 57/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 8.4799 - perplexity: 632.2863
# Epoch 58/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4969 - perplexity: 639.1210
# Epoch 59/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4825 - perplexity: 634.2928
# Epoch 60/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4861 - perplexity: 635.9815
# Epoch 61/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 8.4814 - perplexity: 632.7571
# Epoch 62/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4785 - perplexity: 633.8418
# Epoch 63/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4795 - perplexity: 635.3013
# Epoch 64/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4636 - perplexity: 629.5589
# Epoch 65/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4600 - perplexity: 631.3730
# Epoch 66/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4739 - perplexity: 635.6234
# Epoch 67/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4715 - perplexity: 634.4077
# Epoch 68/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.4627 - perplexity: 629.7829
# Epoch 69/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4646 - perplexity: 633.2678
# Epoch 70/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4626 - perplexity: 631.5059
# Epoch 71/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4574 - perplexity: 632.9583
# Epoch 72/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4600 - perplexity: 633.4709
# Epoch 73/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4576 - perplexity: 631.6383
# Epoch 74/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4629 - perplexity: 629.7689
# Epoch 75/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.4681 - perplexity: 636.1040
# Epoch 76/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4454 - perplexity: 631.4138
# Epoch 77/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4477 - perplexity: 630.6697
# Epoch 78/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4458 - perplexity: 626.8225
# Epoch 79/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4678 - perplexity: 631.5631
# Epoch 80/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4350 - perplexity: 626.6959
# Epoch 81/100
# 2282/2282 [==============================] - 42s 19ms/step - loss: 8.4467 - perplexity: 630.0837
# Epoch 82/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4417 - perplexity: 628.3757
# Epoch 83/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4488 - perplexity: 630.1714
# Epoch 84/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4433 - perplexity: 628.3554
# Epoch 85/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4462 - perplexity: 630.0447
# Epoch 86/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4375 - perplexity: 623.4594
# Epoch 87/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 8.4456 - perplexity: 626.9382
# Epoch 88/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4307 - perplexity: 625.3655
# Epoch 89/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4312 - perplexity: 623.3664
# Epoch 90/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4281 - perplexity: 623.0224
# Epoch 91/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4261 - perplexity: 624.0714
# Epoch 92/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4355 - perplexity: 623.6950
# Epoch 93/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.4311 - perplexity: 626.1994
# Epoch 94/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4352 - perplexity: 623.6480
# Epoch 95/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4259 - perplexity: 623.1398
# Epoch 96/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4344 - perplexity: 626.6828
# Epoch 97/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4368 - perplexity: 627.8666
# Epoch 98/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4217 - perplexity: 623.8033
# Epoch 99/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4185 - perplexity: 621.5299
# Epoch 100/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4134 - perplexity: 617.8134
#
# --------evaluate---------
# 386/386 [==============================] - 5s 11ms/step - loss: 8.6492 - perplexity: 560.7870
# [8.649179458618164, 560.7869873046875]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(35))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.03,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 35)                12040
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 35)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 15301)             550836
# =================================================================
# Total params: 20,562,926
# Trainable params: 562,876
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 42s 17ms/step - loss: 9.5852 - perplexity: 778.5539
# Epoch 2/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 9.3032 - perplexity: 715.5202
# Epoch 3/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.9546 - perplexity: 640.3489
# Epoch 4/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.7683 - perplexity: 624.7229
# Epoch 5/100
# 2282/2282 [==============================] - 42s 18ms/step - loss: 8.6868 - perplexity: 623.2259
# Epoch 6/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.6546 - perplexity: 627.9881
# Epoch 7/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.6212 - perplexity: 630.5416
# Epoch 8/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.6086 - perplexity: 631.5698
# Epoch 9/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.5995 - perplexity: 635.0707
# Epoch 10/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5707 - perplexity: 637.1986
# Epoch 11/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5578 - perplexity: 635.4653
# Epoch 12/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5473 - perplexity: 640.7378
# Epoch 13/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.5645 - perplexity: 643.8816
# Epoch 14/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.5471 - perplexity: 642.7905
# Epoch 15/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.5374 - perplexity: 642.5700
# Epoch 16/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.5304 - perplexity: 644.1750
# Epoch 17/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.5232 - perplexity: 642.8006
# Epoch 18/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.5228 - perplexity: 645.0971
# Epoch 19/100
# 2282/2282 [==============================] - 44s 19ms/step - loss: 8.5106 - perplexity: 642.7918
# Epoch 20/100
# 2282/2282 [==============================] - 43s 19ms/step - loss: 8.4902 - perplexity: 635.6006
# Epoch 21/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.5087 - perplexity: 638.5345
# Epoch 22/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4815 - perplexity: 634.7229
# Epoch 23/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 8.4876 - perplexity: 639.7669
# Epoch 24/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4729 - perplexity: 634.8185
# Epoch 25/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4786 - perplexity: 636.5985
# Epoch 26/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4569 - perplexity: 631.1941
# Epoch 27/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4670 - perplexity: 630.6388
# Epoch 28/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4674 - perplexity: 634.3278
# Epoch 29/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4628 - perplexity: 635.1359
# Epoch 30/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.4488 - perplexity: 625.6800
# Epoch 31/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4422 - perplexity: 633.2130
# Epoch 32/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4371 - perplexity: 627.4510
# Epoch 33/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.4515 - perplexity: 631.1487
# Epoch 34/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4279 - perplexity: 624.3363
# Epoch 35/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.4270 - perplexity: 625.1258
# Epoch 36/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4268 - perplexity: 622.8317
# Epoch 37/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4192 - perplexity: 619.1221
# Epoch 38/100
# 2282/2282 [==============================] - 40s 17ms/step - loss: 8.4214 - perplexity: 622.4898
# Epoch 39/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4077 - perplexity: 618.4770
# Epoch 40/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4079 - perplexity: 619.7842
# Epoch 41/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4166 - perplexity: 623.0434
# Epoch 42/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.4018 - perplexity: 617.6537
# Epoch 43/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.4012 - perplexity: 617.5880
# Epoch 44/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.3926 - perplexity: 612.5056
# Epoch 45/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.3840 - perplexity: 611.5355
# Epoch 46/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.3788 - perplexity: 607.9134
# Epoch 47/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3694 - perplexity: 605.6890
# Epoch 48/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.3711 - perplexity: 606.9221
# Epoch 49/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.3661 - perplexity: 604.7045
# Epoch 50/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 8.3663 - perplexity: 605.3829
# Epoch 51/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.3625 - perplexity: 602.9343
# Epoch 52/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3570 - perplexity: 599.3911
# Epoch 53/100
# 2282/2282 [==============================] - 40s 18ms/step - loss: 8.3460 - perplexity: 598.4750
# Epoch 54/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3494 - perplexity: 596.1270
# Epoch 55/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3492 - perplexity: 595.3430
# Epoch 56/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.3343 - perplexity: 593.1543
# Epoch 57/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3336 - perplexity: 592.3446
# Epoch 58/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.3282 - perplexity: 590.1314
# Epoch 59/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.3219 - perplexity: 586.7256
# Epoch 60/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.3316 - perplexity: 585.3418
# Epoch 61/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.3182 - perplexity: 583.6510
# Epoch 62/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.3120 - perplexity: 583.4579
# Epoch 63/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.2993 - perplexity: 579.4262
# Epoch 64/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.3105 - perplexity: 580.4984
# Epoch 65/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3015 - perplexity: 574.6532
# Epoch 66/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.2979 - perplexity: 577.2867
# Epoch 67/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2913 - perplexity: 570.3882
# Epoch 68/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2776 - perplexity: 568.7279
# Epoch 69/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2726 - perplexity: 565.2721
# Epoch 70/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2707 - perplexity: 564.4946
# Epoch 71/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2703 - perplexity: 563.5417
# Epoch 72/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2728 - perplexity: 564.2562
# Epoch 73/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2600 - perplexity: 558.7534
# Epoch 74/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2577 - perplexity: 559.3033
# Epoch 75/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2363 - perplexity: 554.9669
# Epoch 76/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2407 - perplexity: 555.7883
# Epoch 77/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2460 - perplexity: 555.6028
# Epoch 78/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2358 - perplexity: 552.3042
# Epoch 79/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.2332 - perplexity: 553.4962
# Epoch 80/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2286 - perplexity: 547.2342
# Epoch 81/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 8.2319 - perplexity: 545.6057
# Epoch 82/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2261 - perplexity: 544.3328
# Epoch 83/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.2287 - perplexity: 541.7527
# Epoch 84/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1994 - perplexity: 535.2201
# Epoch 85/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2155 - perplexity: 537.6905
# Epoch 86/100
# 2282/2282 [==============================] - 38s 16ms/step - loss: 8.1989 - perplexity: 533.0215
# Epoch 87/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1894 - perplexity: 530.7093
# Epoch 88/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.1976 - perplexity: 530.3462
# Epoch 89/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1858 - perplexity: 530.8520
# Epoch 90/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.1713 - perplexity: 524.6575
# Epoch 91/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1790 - perplexity: 523.6357
# Epoch 92/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1652 - perplexity: 520.1842
# Epoch 93/100
# 2282/2282 [==============================] - 38s 17ms/step - loss: 8.1779 - perplexity: 519.6386
# Epoch 94/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 8.1610 - perplexity: 517.9082
# Epoch 95/100
# 2282/2282 [==============================] - 39s 17ms/step - loss: 8.1675 - perplexity: 518.6752
# Epoch 96/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1348 - perplexity: 511.9456
# Epoch 97/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.1493 - perplexity: 512.6515
# Epoch 98/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.1373 - perplexity: 511.8324
# Epoch 99/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.1380 - perplexity: 506.5578
# Epoch 100/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1224 - perplexity: 505.1826
#
# --------evaluate---------
# 386/386 [==============================] - 5s 10ms/step - loss: 8.7340 - perplexity: 602.2679
# [8.734025955200195, 602.2678833007812]
#
# --------chart---------

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(35))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.1,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print("\n--------summary---------")
print(model.summary())

print("\n--------fit---------")
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)

print("\n--------evaluate---------")
print(model.evaluate(X_test,y_test))

print("\n--------chart---------")
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])
# Out:
# --------summary---------
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 4, 50)             20000050
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 35)                12040
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 35)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15301)             550836
# =================================================================
# Total params: 20,562,926
# Trainable params: 562,876
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None
#
# --------fit---------
# Epoch 1/100
# 2282/2282 [==============================] - 41s 17ms/step - loss: 9.4132 - perplexity: 741.9571
# Epoch 2/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.7405 - perplexity: 637.2114
# Epoch 3/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.6348 - perplexity: 641.9884
# Epoch 4/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.5838 - perplexity: 642.4123
# Epoch 5/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.5592 - perplexity: 643.7546
# Epoch 6/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 8.5095 - perplexity: 639.8062
# Epoch 7/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 8.4915 - perplexity: 637.2104
# Epoch 8/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.4823 - perplexity: 637.3056
# Epoch 9/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.4615 - perplexity: 627.7878
# Epoch 10/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 8.4269 - perplexity: 621.2623
# Epoch 11/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.4165 - perplexity: 617.3076
# Epoch 12/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.4020 - perplexity: 614.4132
# Epoch 13/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.3803 - perplexity: 607.2796
# Epoch 14/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.3584 - perplexity: 596.4532
# Epoch 15/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.3548 - perplexity: 591.8807
# Epoch 16/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.3394 - perplexity: 586.8308
# Epoch 17/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.3186 - perplexity: 580.1260
# Epoch 18/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 8.3028 - perplexity: 573.4084
# Epoch 19/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.2871 - perplexity: 566.3510
# Epoch 20/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.2638 - perplexity: 555.3787
# Epoch 21/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.2396 - perplexity: 548.5059
# Epoch 22/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.2441 - perplexity: 543.0657
# Epoch 23/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.2218 - perplexity: 533.4316
# Epoch 24/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.2018 - perplexity: 528.2959
# Epoch 25/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.1895 - perplexity: 521.4875
# Epoch 26/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.1664 - perplexity: 514.4178
# Epoch 27/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.1496 - perplexity: 504.8769
# Epoch 28/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.1415 - perplexity: 504.1583
# Epoch 29/100
# 2282/2282 [==============================] - 37s 16ms/step - loss: 8.1142 - perplexity: 493.7260
# Epoch 30/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 8.1020 - perplexity: 487.0388
# Epoch 31/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 8.0981 - perplexity: 481.0009
# Epoch 32/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.0648 - perplexity: 470.0282
# Epoch 33/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.0786 - perplexity: 468.8554
# Epoch 34/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.0471 - perplexity: 461.7417
# Epoch 35/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.0224 - perplexity: 454.6784
# Epoch 36/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 8.0187 - perplexity: 450.5317
# Epoch 37/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 8.0107 - perplexity: 444.7934
# Epoch 38/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.9826 - perplexity: 438.9112
# Epoch 39/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 7.9696 - perplexity: 432.6205
# Epoch 40/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.9544 - perplexity: 428.4046
# Epoch 41/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 7.9477 - perplexity: 421.8344
# Epoch 42/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 7.9477 - perplexity: 419.2901
# Epoch 43/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.9283 - perplexity: 413.8819
# Epoch 44/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 7.9024 - perplexity: 408.6565
# Epoch 45/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.8814 - perplexity: 402.2901
# Epoch 46/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 7.8849 - perplexity: 398.5142
# Epoch 47/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.8672 - perplexity: 393.1280
# Epoch 48/100
# 2282/2282 [==============================] - 35s 16ms/step - loss: 7.8361 - perplexity: 387.6325
# Epoch 49/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.8354 - perplexity: 382.2758
# Epoch 50/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.8159 - perplexity: 378.8287
# Epoch 51/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.8058 - perplexity: 372.9172
# Epoch 52/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.7879 - perplexity: 367.5784
# Epoch 53/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.7742 - perplexity: 364.5429
# Epoch 54/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 7.7696 - perplexity: 362.1149
# Epoch 55/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.7505 - perplexity: 357.6215
# Epoch 56/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.7339 - perplexity: 351.1501
# Epoch 57/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.7283 - perplexity: 350.6082
# Epoch 58/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.7224 - perplexity: 347.6948
# Epoch 59/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.7090 - perplexity: 343.7229
# Epoch 60/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.6889 - perplexity: 339.6437
# Epoch 61/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.6877 - perplexity: 336.9122
# Epoch 62/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.6806 - perplexity: 333.8316
# Epoch 63/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.6560 - perplexity: 331.0300
# Epoch 64/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.6491 - perplexity: 327.2589
# Epoch 65/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.6360 - perplexity: 323.0722
# Epoch 66/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 7.6187 - perplexity: 319.6134
# Epoch 67/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.6229 - perplexity: 319.1568
# Epoch 68/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.6087 - perplexity: 315.5482
# Epoch 69/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.5931 - perplexity: 313.5587
# Epoch 70/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.5992 - perplexity: 308.8168
# Epoch 71/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.5706 - perplexity: 305.3212
# Epoch 72/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.5722 - perplexity: 305.9495
# Epoch 73/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.5569 - perplexity: 302.6353
# Epoch 74/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.5354 - perplexity: 299.5370
# Epoch 75/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.5287 - perplexity: 296.8341
# Epoch 76/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.5037 - perplexity: 293.1277
# Epoch 77/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.5023 - perplexity: 290.9064
# Epoch 78/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.4993 - perplexity: 289.8429
# Epoch 79/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.5048 - perplexity: 291.0190
# Epoch 80/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.4815 - perplexity: 285.7267
# Epoch 81/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.4695 - perplexity: 284.4104
# Epoch 82/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.4639 - perplexity: 282.7970
# Epoch 83/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.4566 - perplexity: 280.7448
# Epoch 84/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.4278 - perplexity: 275.7221
# Epoch 85/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.4218 - perplexity: 273.1890
# Epoch 86/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.4230 - perplexity: 277.4622
# Epoch 87/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.4142 - perplexity: 271.8491
# Epoch 88/100
# 2282/2282 [==============================] - 32s 14ms/step - loss: 7.4031 - perplexity: 272.4691
# Epoch 89/100
# 2282/2282 [==============================] - 33s 15ms/step - loss: 7.3956 - perplexity: 270.4542
# Epoch 90/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.3892 - perplexity: 269.4735
# Epoch 91/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.3810 - perplexity: 267.1299
# Epoch 92/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.3623 - perplexity: 262.9310
# Epoch 93/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.3668 - perplexity: 263.7119
# Epoch 94/100
# 2282/2282 [==============================] - 35s 15ms/step - loss: 7.3513 - perplexity: 261.9914
# Epoch 95/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.3550 - perplexity: 264.2290
# Epoch 96/100
# 2282/2282 [==============================] - 41s 18ms/step - loss: 7.3359 - perplexity: 260.1209
# Epoch 97/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.3367 - perplexity: 259.9016
# Epoch 98/100
# 2282/2282 [==============================] - 34s 15ms/step - loss: 7.3274 - perplexity: 256.5746
# Epoch 99/100
# 2282/2282 [==============================] - 33s 14ms/step - loss: 7.3156 - perplexity: 258.4492
# Epoch 100/100
# 2282/2282 [==============================] - 36s 16ms/step - loss: 7.3068 - perplexity: 255.5455
#
# --------evaluate---------
# 386/386 [==============================] - 4s 8ms/step - loss: 9.0279 - perplexity: 962.4387
# [9.027881622314453, 962.4386596679688]
#
# --------chart---------

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NLP/Project3
# 1/  2/  3/  dataset/  glove.6B.50d.txt

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#Three gram

sequences_train = list()
for i in range(2, len(encoded_train)):
    sequence_train = encoded_train[i-2:i+1]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(2, len(encoded_test)):
    sequence_test = encoded_test[i-2:i+1]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57050
# Total Sequences test: 12346

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 3
# Max Sequences test Length: 3

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras (see above)
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(35))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2, 50)             20000050
# _________________________________________________________________
# lstm (LSTM)                  (None, 35)                12040
# _________________________________________________________________
# dropout (Dropout)            (None, 35)                0
# _________________________________________________________________
# dense (Dense)                (None, 15301)             550836
# =================================================================
# Total params: 20,562,926
# Trainable params: 562,876
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None

# %%
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)
# Out:
# Epoch 1/100
# 2282/2282 [==============================] - 16s 4ms/step - loss: 9.6129 - perplexity: 785.4277
# Epoch 2/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 9.4825 - perplexity: 753.0087
# Epoch 3/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 9.3643 - perplexity: 734.0666
# Epoch 4/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 9.2480 - perplexity: 694.7899
# Epoch 5/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 9.0923 - perplexity: 657.3330
# Epoch 6/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.9511 - perplexity: 635.8990
# Epoch 7/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.8500 - perplexity: 627.7786
# Epoch 8/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.7720 - perplexity: 621.3413
# Epoch 9/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.7278 - perplexity: 618.9662
# Epoch 10/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.6919 - perplexity: 619.9451
# Epoch 11/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.6766 - perplexity: 624.2051
# Epoch 12/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.6456 - perplexity: 623.3986
# Epoch 13/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.6292 - perplexity: 623.2233
# Epoch 14/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.6127 - perplexity: 625.1382
# Epoch 15/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.6031 - perplexity: 626.5899
# Epoch 16/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5804 - perplexity: 625.9177
# Epoch 17/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5864 - perplexity: 630.9456
# Epoch 18/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5634 - perplexity: 629.5708
# Epoch 19/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5716 - perplexity: 632.6942
# Epoch 20/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5644 - perplexity: 637.3864
# Epoch 21/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5481 - perplexity: 632.9852
# Epoch 22/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5331 - perplexity: 632.5905
# Epoch 23/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5347 - perplexity: 633.2159
# Epoch 24/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5323 - perplexity: 636.6158
# Epoch 25/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5320 - perplexity: 640.5483
# Epoch 26/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5069 - perplexity: 634.7321
# Epoch 27/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5282 - perplexity: 642.3560
# Epoch 28/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5245 - perplexity: 642.4174
# Epoch 29/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5032 - perplexity: 635.9877
# Epoch 30/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5078 - perplexity: 638.9966
# Epoch 31/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.5055 - perplexity: 639.4868
# Epoch 32/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4904 - perplexity: 640.4361
# Epoch 33/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4951 - perplexity: 639.1726
# Epoch 34/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4960 - perplexity: 642.2670
# Epoch 35/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4925 - perplexity: 642.2466
# Epoch 36/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4844 - perplexity: 639.3108
# Epoch 37/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4775 - perplexity: 635.9937
# Epoch 38/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4875 - perplexity: 640.9088
# Epoch 39/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4725 - perplexity: 636.8233
# Epoch 40/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4569 - perplexity: 634.1439
# Epoch 41/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4598 - perplexity: 633.7350
# Epoch 42/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4792 - perplexity: 641.2172
# Epoch 43/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4640 - perplexity: 636.1542
# Epoch 44/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4656 - perplexity: 640.6439
# Epoch 45/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4779 - perplexity: 641.0812
# Epoch 46/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4726 - perplexity: 637.9869
# Epoch 47/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4492 - perplexity: 635.8888
# Epoch 48/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4482 - perplexity: 634.8550
# Epoch 49/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4535 - perplexity: 631.8728
# Epoch 50/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4361 - perplexity: 629.0614
# Epoch 51/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4493 - perplexity: 632.9202
# Epoch 52/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4470 - perplexity: 631.2579
# Epoch 53/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4458 - perplexity: 629.7798
# Epoch 54/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4345 - perplexity: 631.2626
# Epoch 55/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4418 - perplexity: 630.3329
# Epoch 56/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4399 - perplexity: 629.7642
# Epoch 57/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4457 - perplexity: 632.9818
# Epoch 58/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4400 - perplexity: 628.8131
# Epoch 59/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4393 - perplexity: 631.0225
# Epoch 60/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4304 - perplexity: 626.9977
# Epoch 61/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4266 - perplexity: 625.7867
# Epoch 62/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4299 - perplexity: 627.6493
# Epoch 63/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4173 - perplexity: 624.3726
# Epoch 64/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4216 - perplexity: 628.1319
# Epoch 65/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4205 - perplexity: 623.9982
# Epoch 66/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4195 - perplexity: 622.3382
# Epoch 67/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4103 - perplexity: 620.6035
# Epoch 68/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4232 - perplexity: 621.4220
# Epoch 69/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4031 - perplexity: 616.9172
# Epoch 70/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4149 - perplexity: 618.9561
# Epoch 71/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4004 - perplexity: 615.6623
# Epoch 72/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4009 - perplexity: 616.9966
# Epoch 73/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4015 - perplexity: 614.4486
# Epoch 74/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4121 - perplexity: 618.8043
# Epoch 75/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4028 - perplexity: 616.3920
# Epoch 76/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4066 - perplexity: 618.7071
# Epoch 77/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3807 - perplexity: 615.5239
# Epoch 78/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3985 - perplexity: 613.3629
# Epoch 79/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4055 - perplexity: 615.7937
# Epoch 80/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3821 - perplexity: 613.8288
# Epoch 81/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3780 - perplexity: 608.8996
# Epoch 82/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.4088 - perplexity: 617.8335
# Epoch 83/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3798 - perplexity: 609.2055
# Epoch 84/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3806 - perplexity: 610.1297
# Epoch 85/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3808 - perplexity: 606.6545
# Epoch 86/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3694 - perplexity: 602.6325
# Epoch 87/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3735 - perplexity: 603.9374
# Epoch 88/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3821 - perplexity: 607.6653
# Epoch 89/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3660 - perplexity: 602.6021
# Epoch 90/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3791 - perplexity: 605.5101
# Epoch 91/100
# 2282/2282 [==============================] - 8s 4ms/step - loss: 8.3661 - perplexity: 603.6795
# Epoch 92/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3621 - perplexity: 601.2392
# Epoch 93/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3624 - perplexity: 596.6073
# Epoch 94/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3645 - perplexity: 598.7964
# Epoch 95/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3761 - perplexity: 605.9911
# Epoch 96/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3629 - perplexity: 598.6701
# Epoch 97/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3512 - perplexity: 597.8938
# Epoch 98/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3557 - perplexity: 593.9278
# Epoch 99/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3504 - perplexity: 593.1225
# Epoch 100/100
# 2282/2282 [==============================] - 9s 4ms/step - loss: 8.3428 - perplexity: 592.4467

# %%
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])

# %%
print(model.evaluate(X_test,y_test))
# Out:
# 386/386 [==============================] - 2s 3ms/step - loss: 8.6477 - perplexity: 557.8184
# [8.647721290588379, 557.8184204101562]

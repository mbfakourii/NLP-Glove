# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/NLP/Project3/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NLP/Project3
# 1/  2/  3/  dataset/  glove.6B.50d.txt

# %%
import numpy as np
import pandas as pd 
import tensorflow as tf 
from keras.layers import Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import losses
from tensorflow.keras import backend
from tensorflow.keras import callbacks
import keras
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input,Dropout
from keras.layers import concatenate,AveragePooling1D,GlobalMaxPooling1D

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# %%
train = load_doc('dataset/train_low.txt')
test = load_doc('dataset/test.txt')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer


def remove_stop_words(value):
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(value)

    filtered_sentence = [word for word in word_tokens if word not in stopwords.words('english')]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    return TreebankWordDetokenizer().detokenize(filtered_sentence).replace('\\', '')

# %%
import nltk
nltk.download('stopwords')
train=remove_stop_words(train)
test=remove_stop_words(test)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tokenizer_train = Tokenizer()
tokenizer_train.fit_on_texts([train])
encoded_train = tokenizer_train.texts_to_sequences([train])[0]

tokenizer_test = Tokenizer()
tokenizer_test.fit_on_texts([test])
encoded_test = tokenizer_test.texts_to_sequences([test])[0]

# %%
vocab_size_train = len(tokenizer_train.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_train)

vocab_size_test = len(tokenizer_test.word_index) + 1
print('Vocabulary Size: %d' % vocab_size_test)
# Out:
# Vocabulary Size: 15301
# Vocabulary Size: 6290

# %%
#four gram

sequences_train = list()
for i in range(3, len(encoded_train)):
    sequence_train = encoded_train[i-2:i+2]
    sequences_train.append(sequence_train)
print('Total Sequences train: %d' % len(sequences_train))    

sequences_test = list()
for i in range(3, len(encoded_test)):
    sequence_test = encoded_test[i-2:i+2]
    sequences_test.append(sequence_test)
print('Total Sequences test: %d' % len(sequences_test))
# Out:
# Total Sequences train: 57049
# Total Sequences test: 12345

# %%
max_length_train = max([len(seq) for seq in sequences_train])
sequences_train = pad_sequences(sequences_train, maxlen=max_length_train, padding='pre')
print('Max Sequences train Length: %d' % max_length_train)

max_length_test = max([len(seq) for seq in sequences_test])
sequences_test = pad_sequences(sequences_test, maxlen=max_length_test, padding='pre')
print('Max Sequences test Length: %d' % max_length_test)
# Out:
# Max Sequences train Length: 4
# Max Sequences test Length: 4

# %%
sequences_train = np.array(sequences_train)
X_train, y_train = sequences_train[:,:-1],sequences_train[:,-1]

sequences_test = np.array(sequences_test)
X_test, y_test = sequences_test[:,:-1],sequences_test[:,-1]

# %%
y_train = to_categorical(y_train, num_classes=vocab_size_train)

# %%
y_test = to_categorical(y_test, num_classes=vocab_size_train)

# %%
def perplexity(y_true, y_pred):
    cross_entropy = losses.categorical_crossentropy(y_true, y_pred)
    perplexity = backend.pow(2.0, cross_entropy)
    return perplexity

# %%
# Prepare Glove File
def readGloveFile(gloveFile):
    with open(gloveFile, 'r') as f:
        wordToGlove = {}  # map from a token (word) to a Glove embedding vector
        wordToIndex = {}  # map from a token to an index
        indexToWord = {}  # map from an index to a token 

        for line in f:
            record = line.strip().split()
            token = record[0] # take the token (word) from the text line
            wordToGlove[token] = np.array(record[1:], dtype=np.float64) # associate the Glove embedding vector to a that token (word)

        tokens = sorted(wordToGlove.keys())
        for idx, tok in enumerate(tokens):
            kerasIdx = idx + 1  # 0 is reserved for masking in Keras (see above)
            wordToIndex[tok] = kerasIdx # associate an index to a token (word)
            indexToWord[kerasIdx] = tok # associate a word to a token (word). Note: inverse of dictionary above

    return wordToIndex, indexToWord, wordToGlove

# Create Pretrained Keras Embedding Layer
def createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, isTrainable):
    vocabLen = len(wordToIndex) + 1  # adding 1 to account for masking
    embDim = next(iter(wordToGlove.values())).shape[0]  # works with any glove dimensions (e.g. 50)

    embeddingMatrix = np.zeros((vocabLen, embDim))  # initialize with zeros
    for word, index in wordToIndex.items():
        embeddingMatrix[index, :] = wordToGlove[word] # create embedding: word index to Glove word embedding

    embeddingLayer = Embedding(vocabLen, embDim, weights=[embeddingMatrix], input_length=max_length_train-1, trainable=isTrainable)
    return embeddingLayer

# usage
wordToIndex, indexToWord, wordToGlove = readGloveFile("glove.6B.50d.txt")
pretrainedEmbeddingLayer = createPretrainedEmbeddingLayer(wordToGlove, wordToIndex, False)

# %%
model = Sequential()
model.add(pretrainedEmbeddingLayer)
model.add(LSTM(35))
model.add(Dropout(0.5))
model.add(Dense(vocab_size_train, activation='softmax'))

gd=tf.keras.optimizers.SGD(
    learning_rate=0.02,
    name='SGD'
)

model.compile(loss='categorical_crossentropy', optimizer=gd, metrics=[perplexity])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 3, 50)             20000050
# _________________________________________________________________
# lstm (LSTM)                  (None, 35)                12040
# _________________________________________________________________
# dropout (Dropout)            (None, 35)                0
# _________________________________________________________________
# dense (Dense)                (None, 15301)             550836
# =================================================================
# Total params: 20,562,926
# Trainable params: 562,876
# Non-trainable params: 20,000,050
# _________________________________________________________________
# None

# %%
metrics = model.fit(X_train, y_train, epochs=100,batch_size=25)
# Out:
# Epoch 1/100
# 2282/2282 [==============================] - 18s 4ms/step - loss: 9.6136 - perplexity: 785.7071
# Epoch 2/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 9.4639 - perplexity: 750.2536
# Epoch 3/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 9.3179 - perplexity: 719.3484
# Epoch 4/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 9.1140 - perplexity: 664.3815
# Epoch 5/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.9233 - perplexity: 634.7916
# Epoch 6/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.7982 - perplexity: 623.8036
# Epoch 7/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.7375 - perplexity: 622.9700
# Epoch 8/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.6989 - perplexity: 624.0475
# Epoch 9/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.6735 - perplexity: 628.6991
# Epoch 10/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.6361 - perplexity: 625.1338
# Epoch 11/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.6177 - perplexity: 628.3204
# Epoch 12/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.6088 - perplexity: 629.6522
# Epoch 13/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.6084 - perplexity: 635.2115
# Epoch 14/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5803 - perplexity: 634.5209
# Epoch 15/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5756 - perplexity: 637.5654
# Epoch 16/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5756 - perplexity: 641.1763
# Epoch 17/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5755 - perplexity: 644.2216
# Epoch 18/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5704 - perplexity: 645.6587
# Epoch 19/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5677 - perplexity: 647.6602
# Epoch 20/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5609 - perplexity: 646.0527
# Epoch 21/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5496 - perplexity: 642.6240
# Epoch 22/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5490 - perplexity: 646.7743
# Epoch 23/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5476 - perplexity: 644.9581
# Epoch 24/100
# 2282/2282 [==============================] - 10s 4ms/step - loss: 8.5433 - perplexity: 645.3025
# Epoch 25/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5419 - perplexity: 649.5464
# Epoch 26/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.5435 - perplexity: 649.1139
# Epoch 27/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5304 - perplexity: 643.7710
# Epoch 28/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5295 - perplexity: 646.9411
# Epoch 29/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5143 - perplexity: 644.5626
# Epoch 30/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5235 - perplexity: 645.0179
# Epoch 31/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5264 - perplexity: 645.5607
# Epoch 32/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5184 - perplexity: 646.0714
# Epoch 33/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.5077 - perplexity: 642.7884
# Epoch 34/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5240 - perplexity: 643.3237
# Epoch 35/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5075 - perplexity: 641.6388
# Epoch 36/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5010 - perplexity: 644.3138
# Epoch 37/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4994 - perplexity: 643.8675
# Epoch 38/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5128 - perplexity: 643.2596
# Epoch 39/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.5091 - perplexity: 644.5245
# Epoch 40/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4869 - perplexity: 639.0259
# Epoch 41/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4962 - perplexity: 640.8803
# Epoch 42/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4910 - perplexity: 641.0737
# Epoch 43/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4795 - perplexity: 635.7914
# Epoch 44/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4727 - perplexity: 637.4745
# Epoch 45/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4757 - perplexity: 630.2447
# Epoch 46/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4730 - perplexity: 637.9551
# Epoch 47/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4718 - perplexity: 634.5713
# Epoch 48/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4724 - perplexity: 639.8234
# Epoch 49/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4759 - perplexity: 637.6071
# Epoch 50/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4722 - perplexity: 635.6568
# Epoch 51/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4744 - perplexity: 640.8852
# Epoch 52/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4746 - perplexity: 637.5344
# Epoch 53/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4505 - perplexity: 634.0715
# Epoch 54/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4692 - perplexity: 638.9946
# Epoch 55/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4590 - perplexity: 635.7134
# Epoch 56/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4470 - perplexity: 633.0784
# Epoch 57/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4487 - perplexity: 628.9591
# Epoch 58/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4412 - perplexity: 630.3043
# Epoch 59/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4484 - perplexity: 633.0065
# Epoch 60/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4466 - perplexity: 632.1758
# Epoch 61/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4514 - perplexity: 631.2738
# Epoch 62/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4515 - perplexity: 631.8485
# Epoch 63/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4487 - perplexity: 630.7822
# Epoch 64/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4362 - perplexity: 628.2764
# Epoch 65/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4292 - perplexity: 625.7180
# Epoch 66/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4349 - perplexity: 629.1383
# Epoch 67/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4299 - perplexity: 628.8572
# Epoch 68/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4323 - perplexity: 625.7459
# Epoch 69/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4246 - perplexity: 622.0752
# Epoch 70/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4205 - perplexity: 625.6645
# Epoch 71/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4189 - perplexity: 625.7764
# Epoch 72/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4082 - perplexity: 618.2291
# Epoch 73/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4119 - perplexity: 618.5054
# Epoch 74/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4008 - perplexity: 618.3148
# Epoch 75/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4171 - perplexity: 620.5649
# Epoch 76/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4087 - perplexity: 614.5170
# Epoch 77/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4090 - perplexity: 617.8857
# Epoch 78/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4027 - perplexity: 616.3914
# Epoch 79/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4088 - perplexity: 620.0886
# Epoch 80/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3932 - perplexity: 611.6932
# Epoch 81/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.4090 - perplexity: 616.8445
# Epoch 82/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4018 - perplexity: 613.8893
# Epoch 83/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.4033 - perplexity: 616.0683
# Epoch 84/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3912 - perplexity: 610.7437
# Epoch 85/100
# 2282/2282 [==============================] - 12s 5ms/step - loss: 8.3895 - perplexity: 612.2293
# Epoch 86/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3834 - perplexity: 609.2060
# Epoch 87/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3969 - perplexity: 611.4856
# Epoch 88/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3799 - perplexity: 607.4467
# Epoch 89/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3925 - perplexity: 610.7126
# Epoch 90/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3832 - perplexity: 607.2372
# Epoch 91/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3953 - perplexity: 609.2626
# Epoch 92/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3815 - perplexity: 606.2313
# Epoch 93/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3744 - perplexity: 606.7990
# Epoch 94/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3828 - perplexity: 606.0183
# Epoch 95/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3739 - perplexity: 603.3729
# Epoch 96/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3562 - perplexity: 600.2907
# Epoch 97/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3655 - perplexity: 598.9091
# Epoch 98/100
# 2282/2282 [==============================] - 11s 5ms/step - loss: 8.3595 - perplexity: 599.6828
# Epoch 99/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3579 - perplexity: 598.8699
# Epoch 100/100
# 2282/2282 [==============================] - 10s 5ms/step - loss: 8.3592 - perplexity: 599.5196

# %%
result = pd.DataFrame.from_dict(metrics.history)
result.plot.line(secondary_y=["loss", "val_loss"])

# %%
print(model.evaluate(X_test,y_test))
# Out:
# 386/386 [==============================] - 2s 3ms/step - loss: 8.6400 - perplexity: 556.1956
# [8.639974594116211, 556.1956176757812]
